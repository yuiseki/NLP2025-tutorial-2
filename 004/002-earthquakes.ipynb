# %%
import duckdb

# DuckDBに接続（インメモリで動作）
conn = duckdb.connect()

# DuckDBに拡張機能をインストール
conn.execute("""
INSTALL httpfs;
INSTALL json;
INSTALL spatial;
""")
conn.execute(f"""
LOAD httpfs;
LOAD json;
LOAD spatial;
""")
conn.execute(f"""
SET s3_region='us-west-2';
""")

# %%
# 国のテーブルを作成（領海を含む）

admin_geojson_url = "https://github.com/nvkelso/natural-earth-vector/raw/master/geojson/ne_110m_admin_0_countries.geojson"
conn.execute(f"CREATE TABLE countries AS SELECT * FROM ST_READ('{admin_geojson_url}')")

# %%
# 地震のテーブルを作成

eq_geojson_url = "https://earthquake.usgs.gov/fdsnws/event/1/query.geojson?starttime=1900-01-01%2000%3A00%3A00&minmagnitude=6&orderby=time"
conn.execute(f"CREATE TABLE earthquakes AS SELECT * FROM ST_READ('{eq_geojson_url}')")

# %%
# NOTE: closeするとDBの内容が失われるのでcloseしてはいけない
# conn.close()

# %%
# NOTE: connはgeojsonを読み込んだものを使い回す必要がある
# conn = duckdb.connect()
summary_of_tables = ""

# SHOWによってテーブル一覧を取得
show_result = conn.execute("SHOW").fetchall()
tables = [row[2] for row in show_result]

for table in tables:
    summary_of_tables += f"Table: {table}\n"
    # DESCRIBE TABLEの結果を文字列に変換
    describe_result = conn.execute(f"DESCRIBE TABLE {table}").fetchall()
    for row in describe_result:
        field_name = row[0]
        field_type = row[1]
        summary_of_tables += f"  Field: {field_name}, {field_type}\n"
print(summary_of_tables)
# Out:
# Table: countries
#   Field: featurecla, VARCHAR
#   Field: scalerank, INTEGER
#   Field: LABELRANK, INTEGER
#   Field: SOVEREIGNT, VARCHAR
#   Field: SOV_A3, VARCHAR
#   Field: ADM0_DIF, INTEGER
#   Field: LEVEL, INTEGER
#   Field: TYPE, VARCHAR
#   Field: TLC, VARCHAR
#   Field: ADMIN, VARCHAR
#   Field: ADM0_A3, VARCHAR
#   Field: GEOU_DIF, INTEGER
#   Field: GEOUNIT, VARCHAR
#   Field: GU_A3, VARCHAR
#   Field: SU_DIF, INTEGER
#   Field: SUBUNIT, VARCHAR
#   Field: SU_A3, VARCHAR
#   Field: BRK_DIFF, INTEGER
#   Field: NAME, VARCHAR
#   Field: NAME_LONG, VARCHAR
#   Field: BRK_A3, VARCHAR
#   Field: BRK_NAME, VARCHAR
#   Field: BRK_GROUP, VARCHAR
#   Field: ABBREV, VARCHAR
#   Field: POSTAL, VARCHAR
#   Field: FORMAL_EN, VARCHAR
#   Field: FORMAL_FR, VARCHAR
#   Field: NAME_CIAWF, VARCHAR
#   Field: NOTE_ADM0, VARCHAR
#   Field: NOTE_BRK, VARCHAR
#   Field: NAME_SORT, VARCHAR
#   Field: NAME_ALT, VARCHAR
#   Field: MAPCOLOR7, INTEGER
#   Field: MAPCOLOR8, INTEGER
#   Field: MAPCOLOR9, INTEGER
#   Field: MAPCOLOR13, INTEGER
#   Field: POP_EST, DOUBLE
#   Field: POP_RANK, INTEGER
#   Field: POP_YEAR, INTEGER
#   Field: GDP_MD, INTEGER
#   Field: GDP_YEAR, INTEGER
#   Field: ECONOMY, VARCHAR
#   Field: INCOME_GRP, VARCHAR
#   Field: FIPS_10, VARCHAR
#   Field: ISO_A2, VARCHAR
#   Field: ISO_A2_EH, VARCHAR
#   Field: ISO_A3, VARCHAR
#   Field: ISO_A3_EH, VARCHAR
#   Field: ISO_N3, VARCHAR
#   Field: ISO_N3_EH, VARCHAR
#   Field: UN_A3, VARCHAR
#   Field: WB_A2, VARCHAR
#   Field: WB_A3, VARCHAR
#   Field: WOE_ID, INTEGER
#   Field: WOE_ID_EH, INTEGER
#   Field: WOE_NOTE, VARCHAR
#   Field: ADM0_ISO, VARCHAR
#   Field: ADM0_DIFF, VARCHAR
#   Field: ADM0_TLC, VARCHAR
#   Field: ADM0_A3_US, VARCHAR
#   Field: ADM0_A3_FR, VARCHAR
#   Field: ADM0_A3_RU, VARCHAR
#   Field: ADM0_A3_ES, VARCHAR
#   Field: ADM0_A3_CN, VARCHAR
#   Field: ADM0_A3_TW, VARCHAR
#   Field: ADM0_A3_IN, VARCHAR
#   Field: ADM0_A3_NP, VARCHAR
#   Field: ADM0_A3_PK, VARCHAR
#   Field: ADM0_A3_DE, VARCHAR
#   Field: ADM0_A3_GB, VARCHAR
#   Field: ADM0_A3_BR, VARCHAR
#   Field: ADM0_A3_IL, VARCHAR
#   Field: ADM0_A3_PS, VARCHAR
#   Field: ADM0_A3_SA, VARCHAR
#   Field: ADM0_A3_EG, VARCHAR
#   Field: ADM0_A3_MA, VARCHAR
#   Field: ADM0_A3_PT, VARCHAR
#   Field: ADM0_A3_AR, VARCHAR
#   Field: ADM0_A3_JP, VARCHAR
#   Field: ADM0_A3_KO, VARCHAR
#   Field: ADM0_A3_VN, VARCHAR
#   Field: ADM0_A3_TR, VARCHAR
#   Field: ADM0_A3_ID, VARCHAR
#   Field: ADM0_A3_PL, VARCHAR
#   Field: ADM0_A3_GR, VARCHAR
#   Field: ADM0_A3_IT, VARCHAR
#   Field: ADM0_A3_NL, VARCHAR
#   Field: ADM0_A3_SE, VARCHAR
#   Field: ADM0_A3_BD, VARCHAR
#   Field: ADM0_A3_UA, VARCHAR
#   Field: ADM0_A3_UN, INTEGER
#   Field: ADM0_A3_WB, INTEGER
#   Field: CONTINENT, VARCHAR
#   Field: REGION_UN, VARCHAR
#   Field: SUBREGION, VARCHAR
#   Field: REGION_WB, VARCHAR
#   Field: NAME_LEN, INTEGER
#   Field: LONG_LEN, INTEGER
#   Field: ABBREV_LEN, INTEGER
#   Field: TINY, INTEGER
#   Field: HOMEPART, INTEGER
#   Field: MIN_ZOOM, DOUBLE
#   Field: MIN_LABEL, DOUBLE
#   Field: MAX_LABEL, DOUBLE
#   Field: LABEL_X, DOUBLE
#   Field: LABEL_Y, DOUBLE
#   Field: NE_ID, INTEGER
#   Field: WIKIDATAID, VARCHAR
#   Field: NAME_AR, VARCHAR
#   Field: NAME_BN, VARCHAR
#   Field: NAME_DE, VARCHAR
#   Field: NAME_EN, VARCHAR
#   Field: NAME_ES, VARCHAR
#   Field: NAME_FA, VARCHAR
#   Field: NAME_FR, VARCHAR
#   Field: NAME_EL, VARCHAR
#   Field: NAME_HE, VARCHAR
#   Field: NAME_HI, VARCHAR
#   Field: NAME_HU, VARCHAR
#   Field: NAME_ID, VARCHAR
#   Field: NAME_IT, VARCHAR
#   Field: NAME_JA, VARCHAR
#   Field: NAME_KO, VARCHAR
#   Field: NAME_NL, VARCHAR
#   Field: NAME_PL, VARCHAR
#   Field: NAME_PT, VARCHAR
#   Field: NAME_RU, VARCHAR
#   Field: NAME_SV, VARCHAR
#   Field: NAME_TR, VARCHAR
#   Field: NAME_UK, VARCHAR
#   Field: NAME_UR, VARCHAR
#   Field: NAME_VI, VARCHAR
#   Field: NAME_ZH, VARCHAR
#   Field: NAME_ZHT, VARCHAR
#   Field: FCLASS_ISO, VARCHAR
#   Field: TLC_DIFF, VARCHAR
#   Field: FCLASS_TLC, VARCHAR
#   Field: FCLASS_US, VARCHAR
#   Field: FCLASS_FR, VARCHAR
#   Field: FCLASS_RU, VARCHAR
#   Field: FCLASS_ES, VARCHAR
#   Field: FCLASS_CN, VARCHAR
#   Field: FCLASS_TW, VARCHAR
#   Field: FCLASS_IN, VARCHAR
#   Field: FCLASS_NP, VARCHAR
#   Field: FCLASS_PK, VARCHAR
#   Field: FCLASS_DE, VARCHAR
#   Field: FCLASS_GB, VARCHAR
#   Field: FCLASS_BR, VARCHAR
#   Field: FCLASS_IL, VARCHAR
#   Field: FCLASS_PS, VARCHAR
#   Field: FCLASS_SA, VARCHAR
#   Field: FCLASS_EG, VARCHAR
#   Field: FCLASS_MA, VARCHAR
#   Field: FCLASS_PT, VARCHAR
#   Field: FCLASS_AR, VARCHAR
#   Field: FCLASS_JP, VARCHAR
#   Field: FCLASS_KO, VARCHAR
#   Field: FCLASS_VN, VARCHAR
#   Field: FCLASS_TR, VARCHAR
#   Field: FCLASS_ID, VARCHAR
#   Field: FCLASS_PL, VARCHAR
#   Field: FCLASS_GR, VARCHAR
#   Field: FCLASS_IT, VARCHAR
#   Field: FCLASS_NL, VARCHAR
#   Field: FCLASS_SE, VARCHAR
#   Field: FCLASS_BD, VARCHAR
#   Field: FCLASS_UA, VARCHAR
#   Field: geom, GEOMETRY
# Table: earthquakes
#   Field: id, VARCHAR
#   Field: mag, DOUBLE
#   Field: place, VARCHAR
#   Field: time, BIGINT
#   Field: updated, BIGINT
#   Field: tz, INTEGER
#   Field: url, VARCHAR
#   Field: detail, VARCHAR
#   Field: felt, INTEGER
#   Field: cdi, DOUBLE
#   Field: mmi, DOUBLE
#   Field: alert, VARCHAR
#   Field: status, VARCHAR
#   Field: tsunami, INTEGER
#   Field: sig, INTEGER
#   Field: net, VARCHAR
#   Field: code, VARCHAR
#   Field: ids, VARCHAR
#   Field: sources, VARCHAR
#   Field: types, VARCHAR
#   Field: nst, INTEGER
#   Field: dmin, DOUBLE
#   Field: rms, DOUBLE
#   Field: gap, DOUBLE
#   Field: magType, VARCHAR
#   Field: type, VARCHAR
#   Field: title, VARCHAR
#   Field: geom, GEOMETRY

# %%
input_text = "国の広さあたりの地震の回数が多い国トップ10を教えて下さい"
print(input_text)
# Out:
# 国の広さあたりの地震の回数が多い国トップ10を教えて下さい

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI

# モデルの準備
model = ChatGoogleGenerativeAI(model="gemini-exp-1206", temperature=0)

# プロンプトの準備
template = """You are an expert of PostgreSQL and PostGIS.
You output the best PostgreSQL query based on given table schema and input text.

You will always reply according to the following rules:
- Output valid PostgreSQL query.
- The query MUST be return name, value and geom columns. Use AS to rename columns.
- The query MUST use ST_AsGeoJSON function to output geom column.
- The query MUST be line delimited and surrounded by just three backquote to indicate that it is a code block.

Hints:
- A3 field of countries table means three-letter country codes defined in ISO 3166-1
- ST_Point treats the SRID as 4326 by default, so there is no need to explicitly set ST_SetSRID.

** Table Schema: **
{table_schema}

User Input:
{input}
"""
prompt = ChatPromptTemplate.from_template(template)

chain = prompt | model

res = chain.invoke({"input": input_text, "table_schema": summary_of_tables})
result = res.content.strip()
print(result)
# Out:
# ```sql
# SELECT
#   c.NAME AS name,
#   COUNT(e.id) / ST_Area(c.geom) AS value,
#   ST_AsGeoJSON(c.geom) AS geom
# FROM
#   countries AS c
#   JOIN earthquakes AS e ON ST_Intersects(c.geom, e.geom)
# GROUP BY
#   c.NAME,
#   c.geom
# ORDER BY
#   value DESC
# LIMIT
#   10;
# ```

# %%
import re
match = re.search(r"```[^\n]*\n(.*?)```", result, re.DOTALL)

if match:
    query = match.group(1).strip()
    print(query)
else:
    print("SQLが見つかりませんでした。")
# Out:
# SELECT
#   c.NAME AS name,
#   COUNT(e.id) / ST_Area(c.geom) AS value,
#   ST_AsGeoJSON(c.geom) AS geom
# FROM
#   countries AS c
#   JOIN earthquakes AS e ON ST_Intersects(c.geom, e.geom)
# GROUP BY
#   c.NAME,
#   c.geom
# ORDER BY
#   value DESC
# LIMIT
#   10;

# %%
duckdb_result = conn.execute(query).fetchall()
duckdb_result
# Out:
# [('Taiwan',
#   23.987808024994848,
#   '{"type":"Polygon","coordinates":[[[121.777818,24.394274],[121.175632,22.790857],[120.74708,21.970571],[120.220083,22.814861],[120.106189,23.556263],[120.69468,24.538451],[121.495044,25.295459],[121.951244,24.997596],[121.777818,24.394274]]]}'),
#  ('Vanuatu',
#   22.17553234756614,
#   '{"type":"MultiPolygon","coordinates":[[[[167.216801,-15.891846],[167.844877,-16.466333],[167.515181,-16.59785],[167.180008,-16.159995],[167.216801,-15.891846]]],[[[166.793158,-15.668811],[166.649859,-15.392704],[166.629137,-14.626497],[167.107712,-14.93392],[167.270028,-15.740021],[167.001207,-15.614602],[166.793158,-15.668811]]]]}'),
#  ('Solomon Is.',
#   11.31540688439896,
#   '{"type":"MultiPolygon","coordinates":[[[[162.119025,-10.482719],[162.398646,-10.826367],[161.700032,-10.820011],[161.319797,-10.204751],[161.917383,-10.446701],[162.119025,-10.482719]]],[[[161.679982,-9.599982],[161.529397,-9.784312],[160.788253,-8.917543],[160.579997,-8.320009],[160.920028,-8.320009],[161.280006,-9.120011],[161.679982,-9.599982]]],[[[160.852229,-9.872937],[160.462588,-9.89521],[159.849447,-9.794027],[159.640003,-9.63998],[159.702945,-9.24295],[160.362956,-9.400304],[160.688518,-9.610162],[160.852229,-9.872937]]],[[[159.640003,-8.020027],[159.875027,-8.33732],[159.917402,-8.53829],[159.133677,-8.114181],[158.586114,-7.754824],[158.21115,-7.421872],[158.359978,-7.320018],[158.820001,-7.560003],[159.640003,-8.020027]]],[[[157.14,-7.021638],[157.538426,-7.34782],[157.33942,-7.404767],[156.90203,-7.176874],[156.491358,-6.765943],[156.542828,-6.599338],[157.14,-7.021638]]]]}'),
#  ('Costa Rica',
#   9.236891343507267,
#   '{"type":"Polygon","coordinates":[[[-82.546196,9.566135],[-82.932891,9.476812],[-82.927155,9.07433],[-82.719183,8.925709],[-82.868657,8.807266],[-82.829771,8.626295],[-82.913176,8.423517],[-82.965783,8.225028],[-83.508437,8.446927],[-83.711474,8.656836],[-83.596313,8.830443],[-83.632642,9.051386],[-83.909886,9.290803],[-84.303402,9.487354],[-84.647644,9.615537],[-84.713351,9.908052],[-84.97566,10.086723],[-84.911375,9.795992],[-85.110923,9.55704],[-85.339488,9.834542],[-85.660787,9.933347],[-85.797445,10.134886],[-85.791709,10.439337],[-85.659314,10.754331],[-85.941725,10.895278],[-85.71254,11.088445],[-85.561852,11.217119],[-84.903003,10.952303],[-84.673069,11.082657],[-84.355931,10.999226],[-84.190179,10.79345],[-83.895054,10.726839],[-83.655612,10.938764],[-83.40232,10.395438],[-83.015677,9.992982],[-82.546196,9.566135]]]}'),
#  ('Papua New Guinea',
#   8.686246956654744,
#   '{"type":"MultiPolygon","coordinates":[[[[141.00021,-2.600151],[142.735247,-3.289153],[144.583971,-3.861418],[145.27318,-4.373738],[145.829786,-4.876498],[145.981922,-5.465609],[147.648073,-6.083659],[147.891108,-6.614015],[146.970905,-6.721657],[147.191874,-7.388024],[148.084636,-8.044108],[148.734105,-9.104664],[149.306835,-9.071436],[149.266631,-9.514406],[150.038728,-9.684318],[149.738798,-9.872937],[150.801628,-10.293687],[150.690575,-10.582713],[150.028393,-10.652476],[149.78231,-10.393267],[148.923138,-10.280923],[147.913018,-10.130441],[147.135443,-9.492444],[146.567881,-8.942555],[146.048481,-8.067414],[144.744168,-7.630128],[143.897088,-7.91533],[143.286376,-8.245491],[143.413913,-8.983069],[142.628431,-9.326821],[142.068259,-9.159596],[141.033852,-9.117893],[141.017057,-5.859022],[141.00021,-2.600151]]],[[[152.640017,-3.659983],[153.019994,-3.980015],[153.140038,-4.499983],[152.827292,-4.766427],[152.638673,-4.176127],[152.406026,-3.789743],[151.953237,-3.462062],[151.384279,-3.035422],[150.66205,-2.741486],[150.939965,-2.500002],[151.479984,-2.779985],[151.820015,-2.999972],[152.239989,-3.240009],[152.640017,-3.659983]]],[[[151.30139,-5.840728],[150.754447,-6.083763],[150.241197,-6.317754],[149.709963,-6.316513],[148.890065,-6.02604],[148.318937,-5.747142],[148.401826,-5.437756],[149.298412,-5.583742],[149.845562,-5.505503],[149.99625,-5.026101],[150.139756,-5.001348],[150.236908,-5.53222],[150.807467,-5.455842],[151.089672,-5.113693],[151.647881,-4.757074],[151.537862,-4.167807],[152.136792,-4.14879],[152.338743,-4.312966],[152.318693,-4.867661],[151.982796,-5.478063],[151.459107,-5.56028],[151.30139,-5.840728]]],[[[154.759991,-5.339984],[155.062918,-5.566792],[155.547746,-6.200655],[156.019965,-6.540014],[155.880026,-6.819997],[155.599991,-6.919991],[155.166994,-6.535931],[154.729192,-5.900828],[154.514114,-5.139118],[154.652504,-5.042431],[154.759991,-5.339984]]]]}'),
#  ('El Salvador',
#   5.154379253103478,
#   '{"type":"Polygon","coordinates":[[[-89.353326,14.424133],[-89.058512,14.340029],[-88.843073,14.140507],[-88.541231,13.980155],[-88.503998,13.845486],[-88.065343,13.964626],[-87.859515,13.893312],[-87.723503,13.78505],[-87.793111,13.38448],[-87.904112,13.149017],[-88.483302,13.163951],[-88.843228,13.259734],[-89.256743,13.458533],[-89.812394,13.520622],[-90.095555,13.735338],[-90.064678,13.88197],[-89.721934,14.134228],[-89.534219,14.244816],[-89.587343,14.362586],[-89.353326,14.424133]]]}'),
#  ('Philippines',
#   4.446414786897268,
#   '{"type":"MultiPolygon","coordinates":[[[[120.833896,12.704496],[120.323436,13.466413],[121.180128,13.429697],[121.527394,13.06959],[121.26219,12.20556],[120.833896,12.704496]]],[[[122.586089,9.981045],[122.837081,10.261157],[122.947411,10.881868],[123.49885,10.940624],[123.337774,10.267384],[124.077936,11.232726],[123.982438,10.278779],[123.623183,9.950091],[123.309921,9.318269],[122.995883,9.022189],[122.380055,9.713361],[122.586089,9.981045]]],[[[126.376814,8.414706],[126.478513,7.750354],[126.537424,7.189381],[126.196773,6.274294],[125.831421,7.293715],[125.363852,6.786485],[125.683161,6.049657],[125.396512,5.581003],[124.219788,6.161355],[123.93872,6.885136],[124.243662,7.36061],[123.610212,7.833527],[123.296071,7.418876],[122.825506,7.457375],[122.085499,6.899424],[121.919928,7.192119],[122.312359,8.034962],[122.942398,8.316237],[123.487688,8.69301],[123.841154,8.240324],[124.60147,8.514158],[124.764612,8.960409],[125.471391,8.986997],[125.412118,9.760335],[126.222714,9.286074],[126.306637,8.782487],[126.376814,8.414706]]],[[[118.504581,9.316383],[117.174275,8.3675],[117.664477,9.066889],[118.386914,9.6845],[118.987342,10.376292],[119.511496,11.369668],[119.689677,10.554291],[119.029458,10.003653],[118.504581,9.316383]]],[[[122.336957,18.224883],[122.174279,17.810283],[122.515654,17.093505],[122.252311,16.262444],[121.662786,15.931018],[121.50507,15.124814],[121.728829,14.328376],[122.258925,14.218202],[122.701276,14.336541],[123.950295,13.782131],[123.855107,13.237771],[124.181289,12.997527],[124.077419,12.536677],[123.298035,13.027526],[122.928652,13.55292],[122.671355,13.185836],[122.03465,13.784482],[121.126385,13.636687],[120.628637,13.857656],[120.679384,14.271016],[120.991819,14.525393],[120.693336,14.756671],[120.564145,14.396279],[120.070429,14.970869],[119.920929,15.406347],[119.883773,16.363704],[120.286488,16.034629],[120.390047,17.599081],[120.715867,18.505227],[121.321308,18.504065],[121.937601,18.218552],[122.246006,18.47895],[122.336957,18.224883]]],[[[122.03837,11.415841],[121.883548,11.891755],[122.483821,11.582187],[123.120217,11.58366],[123.100838,11.165934],[122.637714,10.741308],[122.00261,10.441017],[121.967367,10.905691],[122.03837,11.415841]]],[[[125.502552,12.162695],[125.783465,11.046122],[125.011884,11.311455],[125.032761,10.975816],[125.277449,10.358722],[124.801819,10.134679],[124.760168,10.837995],[124.459101,10.88993],[124.302522,11.495371],[124.891013,11.415583],[124.87799,11.79419],[124.266762,12.557761],[125.227116,12.535721],[125.502552,12.162695]]]]}'),
#  ('Guatemala',
#   3.684249650834931,
#   '{"type":"Polygon","coordinates":[[[-92.22775,14.538829],[-92.20323,14.830103],[-92.087216,15.064585],[-92.229249,15.251447],[-91.74796,16.066565],[-90.464473,16.069562],[-90.438867,16.41011],[-90.600847,16.470778],[-90.711822,16.687483],[-91.08167,16.918477],[-91.453921,17.252177],[-91.002269,17.254658],[-91.00152,17.817595],[-90.067934,17.819326],[-89.14308,17.808319],[-89.150806,17.015577],[-89.229122,15.886938],[-88.930613,15.887273],[-88.604586,15.70638],[-88.518364,15.855389],[-88.225023,15.727722],[-88.68068,15.346247],[-89.154811,15.066419],[-89.22522,14.874286],[-89.145535,14.678019],[-89.353326,14.424133],[-89.587343,14.362586],[-89.534219,14.244816],[-89.721934,14.134228],[-90.064678,13.88197],[-90.095555,13.735338],[-90.608624,13.909771],[-91.23241,13.927832],[-91.689747,14.126218],[-92.22775,14.538829]]]}'),
#  ('Greece',
#   3.492436682631141,
#   '{"type":"MultiPolygon","coordinates":[[[[26.290003,35.29999],[26.164998,35.004995],[24.724982,34.919988],[24.735007,35.084991],[23.514978,35.279992],[23.69998,35.705004],[24.246665,35.368022],[25.025015,35.424996],[25.769208,35.354018],[25.745023,35.179998],[26.290003,35.29999]]],[[[22.952377,41.337994],[23.692074,41.309081],[24.492645,41.583896],[25.197201,41.234486],[26.106138,41.328899],[26.117042,41.826905],[26.604196,41.562115],[26.294602,40.936261],[26.056942,40.824123],[25.447677,40.852545],[24.925848,40.947062],[23.714811,40.687129],[24.407999,40.124993],[23.899968,39.962006],[23.342999,39.960998],[22.813988,40.476005],[22.626299,40.256561],[22.849748,39.659311],[23.350027,39.190011],[22.973099,38.970903],[23.530016,38.510001],[24.025025,38.219993],[24.040011,37.655015],[23.115003,37.920011],[23.409972,37.409991],[22.774972,37.30501],[23.154225,36.422506],[22.490028,36.41],[21.670026,36.844986],[21.295011,37.644989],[21.120034,38.310323],[20.730032,38.769985],[20.217712,39.340235],[20.150016,39.624998],[20.615,40.110007],[20.674997,40.435],[20.99999,40.580004],[21.02004,40.842727],[21.674161,40.931275],[22.055378,41.149866],[22.597308,41.130487],[22.76177,41.3048],[22.952377,41.337994]]]]}'),
#  ('Chile',
#   2.8552117139762077,
#   '{"type":"MultiPolygon","coordinates":[[[[-68.63401,-52.63637],[-68.63335,-54.8695],[-67.56244,-54.87001],[-66.95992,-54.89681],[-67.29103,-55.30124],[-68.14863,-55.61183],[-68.639991,-55.580018],[-69.2321,-55.49906],[-69.95809,-55.19843],[-71.00568,-55.05383],[-72.2639,-54.49514],[-73.2852,-53.95752],[-74.66253,-52.83749],[-73.8381,-53.04743],[-72.43418,-53.7154],[-71.10773,-54.07433],[-70.59178,-53.61583],[-70.26748,-52.93123],[-69.34565,-52.5183],[-68.63401,-52.63637]]],[[[-69.590424,-17.580012],[-69.100247,-18.260125],[-68.966818,-18.981683],[-68.442225,-19.405068],[-68.757167,-20.372658],[-68.219913,-21.494347],[-67.82818,-22.872919],[-67.106674,-22.735925],[-66.985234,-22.986349],[-67.328443,-24.025303],[-68.417653,-24.518555],[-68.386001,-26.185016],[-68.5948,-26.506909],[-68.295542,-26.89934],[-69.001235,-27.521214],[-69.65613,-28.459141],[-70.01355,-29.367923],[-69.919008,-30.336339],[-70.535069,-31.36501],[-70.074399,-33.09121],[-69.814777,-33.273886],[-69.817309,-34.193571],[-70.388049,-35.169688],[-70.364769,-36.005089],[-71.121881,-36.658124],[-71.118625,-37.576827],[-70.814664,-38.552995],[-71.413517,-38.916022],[-71.680761,-39.808164],[-71.915734,-40.832339],[-71.746804,-42.051386],[-72.148898,-42.254888],[-71.915424,-43.408565],[-71.464056,-43.787611],[-71.793623,-44.207172],[-71.329801,-44.407522],[-71.222779,-44.784243],[-71.659316,-44.973689],[-71.552009,-45.560733],[-71.917258,-46.884838],[-72.447355,-47.738533],[-72.331161,-48.244238],[-72.648247,-48.878618],[-73.415436,-49.318436],[-73.328051,-50.378785],[-72.975747,-50.74145],[-72.309974,-50.67701],[-72.329404,-51.425956],[-71.914804,-52.009022],[-69.498362,-52.142761],[-68.571545,-52.299444],[-69.461284,-52.291951],[-69.94278,-52.537931],[-70.845102,-52.899201],[-71.006332,-53.833252],[-71.429795,-53.856455],[-72.557943,-53.53141],[-73.702757,-52.835069],[-73.702757,-52.83507],[-74.946763,-52.262754],[-75.260026,-51.629355],[-74.976632,-51.043396],[-75.479754,-50.378372],[-75.608015,-48.673773],[-75.18277,-47.711919],[-74.126581,-46.939253],[-75.644395,-46.647643],[-74.692154,-45.763976],[-74.351709,-44.103044],[-73.240356,-44.454961],[-72.717804,-42.383356],[-73.3889,-42.117532],[-73.701336,-43.365776],[-74.331943,-43.224958],[-74.017957,-41.794813],[-73.677099,-39.942213],[-73.217593,-39.258689],[-73.505559,-38.282883],[-73.588061,-37.156285],[-73.166717,-37.12378],[-72.553137,-35.50884],[-71.861732,-33.909093],[-71.43845,-32.418899],[-71.668721,-30.920645],[-71.370083,-30.095682],[-71.489894,-28.861442],[-70.905124,-27.64038],[-70.724954,-25.705924],[-70.403966,-23.628997],[-70.091246,-21.393319],[-70.16442,-19.756468],[-70.372572,-18.347975],[-69.858444,-18.092694],[-69.590424,-17.580012]]]]}')]

# %%
# duckdb_resultをGeoJSONに変換する

import json

def duckdb_result_to_geojson(duckdb_result):
    geojson = {
        "type": "FeatureCollection",
        "features": []
    }

    for row in duckdb_result:
        try:
            name, value, geom_str = row
            geom = json.loads(geom_str)
            feature = {
                "type": "Feature",
                "geometry": geom,
                "properties": {
                    "name": name,
                    "value": value
                }
            }
            geojson["features"].append(feature)
        except (ValueError, TypeError, IndexError) as e:
            print(f"Error processing row {row}: {e}")
            return None  # Return None if any row fails
        except Exception as e:
            print(f"An unexpected error occurred: {e}")
            return None

    return json.dumps(geojson, indent=2)



geojson_output = duckdb_result_to_geojson(duckdb_result)

if geojson_output:
    print(geojson_output)
else:
    print("Failed to convert DuckDB result to GeoJSON.")
# Out:
# {
#   "type": "FeatureCollection",
#   "features": [
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               121.777818,
#               24.394274
#             ],
#             [
#               121.175632,
#               22.790857
#             ],
#             [
#               120.74708,
#               21.970571
#             ],
#             [
#               120.220083,
#               22.814861
#             ],
#             [
#               120.106189,
#               23.556263
#             ],
#             [
#               120.69468,
#               24.538451
#             ],
#             [
#               121.495044,
#               25.295459
#             ],
#             [
#               121.951244,
#               24.997596
#             ],
#             [
#               121.777818,
#               24.394274
#             ]
#           ]
#         ]
#       },
#       "properties": {
#         "name": "Taiwan",
#         "value": 23.987808024994848
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "MultiPolygon",
#         "coordinates": [
#           [
#             [
#               [
#                 167.216801,
#                 -15.891846
#               ],
#               [
#                 167.844877,
#                 -16.466333
#               ],
#               [
#                 167.515181,
#                 -16.59785
#               ],
#               [
#                 167.180008,
#                 -16.159995
#               ],
#               [
#                 167.216801,
#                 -15.891846
#               ]
#             ]
#           ],
#           [
#             [
#               [
#                 166.793158,
#                 -15.668811
#               ],
#               [
#                 166.649859,
#                 -15.392704
#               ],
#               [
#                 166.629137,
#                 -14.626497
#               ],
#               [
#                 167.107712,
#                 -14.93392
#               ],
#               [
#                 167.270028,
#                 -15.740021
#               ],
#               [
#                 167.001207,
#                 -15.614602
#               ],
#               [
#                 166.793158,
#                 -15.668811
#               ]
#             ]
#           ]
#         ]
#       },
#       "properties": {
#         "name": "Vanuatu",
#         "value": 22.17553234756614
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "MultiPolygon",
#         "coordinates": [
#           [
#             [
#               [
#                 162.119025,
#                 -10.482719
#               ],
#               [
#                 162.398646,
#                 -10.826367
#               ],
#               [
#                 161.700032,
#                 -10.820011
#               ],
#               [
#                 161.319797,
#                 -10.204751
#               ],
#               [
#                 161.917383,
#                 -10.446701
#               ],
#               [
#                 162.119025,
#                 -10.482719
#               ]
#             ]
#           ],
#           [
#             [
#               [
#                 161.679982,
#                 -9.599982
#               ],
#               [
#                 161.529397,
#                 -9.784312
#               ],
#               [
#                 160.788253,
#                 -8.917543
#               ],
#               [
#                 160.579997,
#                 -8.320009
#               ],
#               [
#                 160.920028,
#                 -8.320009
#               ],
#               [
#                 161.280006,
#                 -9.120011
#               ],
#               [
#                 161.679982,
#                 -9.599982
#               ]
#             ]
#           ],
#           [
#             [
#               [
#                 160.852229,
#                 -9.872937
#               ],
#               [
#                 160.462588,
#                 -9.89521
#               ],
#               [
#                 159.849447,
#                 -9.794027
#               ],
#               [
#                 159.640003,
#                 -9.63998
#               ],
#               [
#                 159.702945,
#                 -9.24295
#               ],
#               [
#                 160.362956,
#                 -9.400304
#               ],
#               [
#                 160.688518,
#                 -9.610162
#               ],
#               [
#                 160.852229,
#                 -9.872937
#               ]
#             ]
#           ],
#           [
#             [
#               [
#                 159.640003,
#                 -8.020027
#               ],
#               [
#                 159.875027,
#                 -8.33732
#               ],
#               [
#                 159.917402,
#                 -8.53829
#               ],
#               [
#                 159.133677,
#                 -8.114181
#               ],
#               [
#                 158.586114,
#                 -7.754824
#               ],
#               [
#                 158.21115,
#                 -7.421872
#               ],
#               [
#                 158.359978,
#                 -7.320018
#               ],
#               [
#                 158.820001,
#                 -7.560003
#               ],
#               [
#                 159.640003,
#                 -8.020027
#               ]
#             ]
#           ],
#           [
#             [
#               [
#                 157.14,
#                 -7.021638
#               ],
#               [
#                 157.538426,
#                 -7.34782
#               ],
#               [
#                 157.33942,
#                 -7.404767
#               ],
#               [
#                 156.90203,
#                 -7.176874
#               ],
#               [
#                 156.491358,
#                 -6.765943
#               ],
#               [
#                 156.542828,
#                 -6.599338
#               ],
#               [
#                 157.14,
#                 -7.021638
#               ]
#             ]
#           ]
#         ]
#       },
#       "properties": {
#         "name": "Solomon Is.",
#         "value": 11.31540688439896
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               -82.546196,
#               9.566135
#             ],
#             [
#               -82.932891,
#               9.476812
#             ],
#             [
#               -82.927155,
#               9.07433
#             ],
#             [
#               -82.719183,
#               8.925709
#             ],
#             [
#               -82.868657,
#               8.807266
#             ],
#             [
#               -82.829771,
#               8.626295
#             ],
#             [
#               -82.913176,
#               8.423517
#             ],
#             [
#               -82.965783,
#               8.225028
#             ],
#             [
#               -83.508437,
#               8.446927
#             ],
#             [
#               -83.711474,
#               8.656836
#             ],
#             [
#               -83.596313,
#               8.830443
#             ],
#             [
#               -83.632642,
#               9.051386
#             ],
#             [
#               -83.909886,
#               9.290803
#             ],
#             [
#               -84.303402,
#               9.487354
#             ],
#             [
#               -84.647644,
#               9.615537
#             ],
#             [
#               -84.713351,
#               9.908052
#             ],
#             [
#               -84.97566,
#               10.086723
#             ],
#             [
#               -84.911375,
#               9.795992
#             ],
#             [
#               -85.110923,
#               9.55704
#             ],
#             [
#               -85.339488,
#               9.834542
#             ],
#             [
#               -85.660787,
#               9.933347
#             ],
#             [
#               -85.797445,
#               10.134886
#             ],
#             [
#               -85.791709,
#               10.439337
#             ],
#             [
#               -85.659314,
#               10.754331
#             ],
#             [
#               -85.941725,
#               10.895278
#             ],
#             [
#               -85.71254,
#               11.088445
#             ],
#             [
#               -85.561852,
#               11.217119
#             ],
#             [
#               -84.903003,
#               10.952303
#             ],
#             [
#               -84.673069,
#               11.082657
#             ],
#             [
#               -84.355931,
#               10.999226
#             ],
#             [
#               -84.190179,
#               10.79345
#             ],
#             [
#               -83.895054,
#               10.726839
#             ],
#             [
#               -83.655612,
#               10.938764
#             ],
#             [
#               -83.40232,
#               10.395438
#             ],
#             [
#               -83.015677,
#               9.992982
#             ],
#             [
#               -82.546196,
#               9.566135
#             ]
#           ]
#         ]
#       },
#       "properties": {
#         "name": "Costa Rica",
#         "value": 9.236891343507267
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "MultiPolygon",
#         "coordinates": [
#           [
#             [
#               [
#                 141.00021,
#                 -2.600151
#               ],
#               [
#                 142.735247,
#                 -3.289153
#               ],
#               [
#                 144.583971,
#                 -3.861418
#               ],
#               [
#                 145.27318,
#                 -4.373738
#               ],
#               [
#                 145.829786,
#                 -4.876498
#               ],
#               [
#                 145.981922,
#                 -5.465609
#               ],
#               [
#                 147.648073,
#                 -6.083659
#               ],
#               [
#                 147.891108,
#                 -6.614015
#               ],
#               [
#                 146.970905,
#                 -6.721657
#               ],
#               [
#                 147.191874,
#                 -7.388024
#               ],
#               [
#                 148.084636,
#                 -8.044108
#               ],
#               [
#                 148.734105,
#                 -9.104664
#               ],
#               [
#                 149.306835,
#                 -9.071436
#               ],
#               [
#                 149.266631,
#                 -9.514406
#               ],
#               [
#                 150.038728,
#                 -9.684318
#               ],
#               [
#                 149.738798,
#                 -9.872937
#               ],
#               [
#                 150.801628,
#                 -10.293687
#               ],
#               [
#                 150.690575,
#                 -10.582713
#               ],
#               [
#                 150.028393,
#                 -10.652476
#               ],
#               [
#                 149.78231,
#                 -10.393267
#               ],
#               [
#                 148.923138,
#                 -10.280923
#               ],
#               [
#                 147.913018,
#                 -10.130441
#               ],
#               [
#                 147.135443,
#                 -9.492444
#               ],
#               [
#                 146.567881,
#                 -8.942555
#               ],
#               [
#                 146.048481,
#                 -8.067414
#               ],
#               [
#                 144.744168,
#                 -7.630128
#               ],
#               [
#                 143.897088,
#                 -7.91533
#               ],
#               [
#                 143.286376,
#                 -8.245491
#               ],
#               [
#                 143.413913,
#                 -8.983069
#               ],
#               [
#                 142.628431,
#                 -9.326821
#               ],
#               [
#                 142.068259,
#                 -9.159596
#               ],
#               [
#                 141.033852,
#                 -9.117893
#               ],
#               [
#                 141.017057,
#                 -5.859022
#               ],
#               [
#                 141.00021,
#                 -2.600151
#               ]
#             ]
#           ],
#           [
#             [
#               [
#                 152.640017,
#                 -3.659983
#               ],
#               [
#                 153.019994,
#                 -3.980015
#               ],
#               [
#                 153.140038,
#                 -4.499983
#               ],
#               [
#                 152.827292,
#                 -4.766427
#               ],
#               [
#                 152.638673,
#                 -4.176127
#               ],
#               [
#                 152.406026,
#                 -3.789743
#               ],
#               [
#                 151.953237,
#                 -3.462062
#               ],
#               [
#                 151.384279,
#                 -3.035422
#               ],
#               [
#                 150.66205,
#                 -2.741486
#               ],
#               [
#                 150.939965,
#                 -2.500002
#               ],
#               [
#                 151.479984,
#                 -2.779985
#               ],
#               [
#                 151.820015,
#                 -2.999972
#               ],
#               [
#                 152.239989,
#                 -3.240009
#               ],
#               [
#                 152.640017,
#                 -3.659983
#               ]
#             ]
#           ],
#           [
#             [
#               [
#                 151.30139,
#                 -5.840728
#               ],
#               [
#                 150.754447,
#                 -6.083763
#               ],
#               [
#                 150.241197,
#                 -6.317754
#               ],
#               [
#                 149.709963,
#                 -6.316513
#               ],
#               [
#                 148.890065,
#                 -6.02604
#               ],
#               [
#                 148.318937,
#                 -5.747142
#               ],
#               [
#                 148.401826,
#                 -5.437756
#               ],
#               [
#                 149.298412,
#                 -5.583742
#               ],
#               [
#                 149.845562,
#                 -5.505503
#               ],
#               [
#                 149.99625,
#                 -5.026101
#               ],
#               [
#                 150.139756,
#                 -5.001348
#               ],
#               [
#                 150.236908,
#                 -5.53222
#               ],
#               [
#                 150.807467,
#                 -5.455842
#               ],
#               [
#                 151.089672,
#                 -5.113693
#               ],
#               [
#                 151.647881,
#                 -4.757074
#               ],
#               [
#                 151.537862,
#                 -4.167807
#               ],
#               [
#                 152.136792,
#                 -4.14879
#               ],
#               [
#                 152.338743,
#                 -4.312966
#               ],
#               [
#                 152.318693,
#                 -4.867661
#               ],
#               [
#                 151.982796,
#                 -5.478063
#               ],
#               [
#                 151.459107,
#                 -5.56028
#               ],
#               [
#                 151.30139,
#                 -5.840728
#               ]
#             ]
#           ],
#           [
#             [
#               [
#                 154.759991,
#                 -5.339984
#               ],
#               [
#                 155.062918,
#                 -5.566792
#               ],
#               [
#                 155.547746,
#                 -6.200655
#               ],
#               [
#                 156.019965,
#                 -6.540014
#               ],
#               [
#                 155.880026,
#                 -6.819997
#               ],
#               [
#                 155.599991,
#                 -6.919991
#               ],
#               [
#                 155.166994,
#                 -6.535931
#               ],
#               [
#                 154.729192,
#                 -5.900828
#               ],
#               [
#                 154.514114,
#                 -5.139118
#               ],
#               [
#                 154.652504,
#                 -5.042431
#               ],
#               [
#                 154.759991,
#                 -5.339984
#               ]
#             ]
#           ]
#         ]
#       },
#       "properties": {
#         "name": "Papua New Guinea",
#         "value": 8.686246956654744
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               -89.353326,
#               14.424133
#             ],
#             [
#               -89.058512,
#               14.340029
#             ],
#             [
#               -88.843073,
#               14.140507
#             ],
#             [
#               -88.541231,
#               13.980155
#             ],
#             [
#               -88.503998,
#               13.845486
#             ],
#             [
#               -88.065343,
#               13.964626
#             ],
#             [
#               -87.859515,
#               13.893312
#             ],
#             [
#               -87.723503,
#               13.78505
#             ],
#             [
#               -87.793111,
#               13.38448
#             ],
#             [
#               -87.904112,
#               13.149017
#             ],
#             [
#               -88.483302,
#               13.163951
#             ],
#             [
#               -88.843228,
#               13.259734
#             ],
#             [
#               -89.256743,
#               13.458533
#             ],
#             [
#               -89.812394,
#               13.520622
#             ],
#             [
#               -90.095555,
#               13.735338
#             ],
#             [
#               -90.064678,
#               13.88197
#             ],
#             [
#               -89.721934,
#               14.134228
#             ],
#             [
#               -89.534219,
#               14.244816
#             ],
#             [
#               -89.587343,
#               14.362586
#             ],
#             [
#               -89.353326,
#               14.424133
#             ]
#           ]
#         ]
#       },
#       "properties": {
#         "name": "El Salvador",
#         "value": 5.154379253103478
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "MultiPolygon",
#         "coordinates": [
#           [
#             [
#               [
#                 120.833896,
#                 12.704496
#               ],
#               [
#                 120.323436,
#                 13.466413
#               ],
#               [
#                 121.180128,
#                 13.429697
#               ],
#               [
#                 121.527394,
#                 13.06959
#               ],
#               [
#                 121.26219,
#                 12.20556
#               ],
#               [
#                 120.833896,
#                 12.704496
#               ]
#             ]
#           ],
#           [
#             [
#               [
#                 122.586089,
#                 9.981045
#               ],
#               [
#                 122.837081,
#                 10.261157
#               ],
#               [
#                 122.947411,
#                 10.881868
#               ],
#               [
#                 123.49885,
#                 10.940624
#               ],
#               [
#                 123.337774,
#                 10.267384
#               ],
#               [
#                 124.077936,
#                 11.232726
#               ],
#               [
#                 123.982438,
#                 10.278779
#               ],
#               [
#                 123.623183,
#                 9.950091
#               ],
#               [
#                 123.309921,
#                 9.318269
#               ],
#               [
#                 122.995883,
#                 9.022189
#               ],
#               [
#                 122.380055,
#                 9.713361
#               ],
#               [
#                 122.586089,
#                 9.981045
#               ]
#             ]
#           ],
#           [
#             [
#               [
#                 126.376814,
#                 8.414706
#               ],
#               [
#                 126.478513,
#                 7.750354
#               ],
#               [
#                 126.537424,
#                 7.189381
#               ],
#               [
#                 126.196773,
#                 6.274294
#               ],
#               [
#                 125.831421,
#                 7.293715
#               ],
#               [
#                 125.363852,
#                 6.786485
#               ],
#               [
#                 125.683161,
#                 6.049657
#               ],
#               [
#                 125.396512,
#                 5.581003
#               ],
#               [
#                 124.219788,
#                 6.161355
#               ],
#               [
#                 123.93872,
#                 6.885136
#               ],
#               [
#                 124.243662,
#                 7.36061
#               ],
#               [
#                 123.610212,
#                 7.833527
#               ],
#               [
#                 123.296071,
#                 7.418876
#               ],
#               [
#                 122.825506,
#                 7.457375
#               ],
#               [
#                 122.085499,
#                 6.899424
#               ],
#               [
#                 121.919928,
#                 7.192119
#               ],
#               [
#                 122.312359,
#                 8.034962
#               ],
#               [
#                 122.942398,
#                 8.316237
#               ],
#               [
#                 123.487688,
#                 8.69301
#               ],
#               [
#                 123.841154,
#                 8.240324
#               ],
#               [
#                 124.60147,
#                 8.514158
#               ],
#               [
#                 124.764612,
#                 8.960409
#               ],
#               [
#                 125.471391,
#                 8.986997
#               ],
#               [
#                 125.412118,
#                 9.760335
#               ],
#               [
#                 126.222714,
#                 9.286074
#               ],
#               [
#                 126.306637,
#                 8.782487
#               ],
#               [
#                 126.376814,
#                 8.414706
#               ]
#             ]
#           ],
#           [
#             [
#               [
#                 118.504581,
#                 9.316383
#               ],
#               [
#                 117.174275,
#                 8.3675
#               ],
#               [
#                 117.664477,
#                 9.066889
#               ],
#               [
#                 118.386914,
#                 9.6845
#               ],
#               [
#                 118.987342,
#                 10.376292
#               ],
#               [
#                 119.511496,
#                 11.369668
#               ],
#               [
#                 119.689677,
#                 10.554291
#               ],
#               [
#                 119.029458,
#                 10.003653
#               ],
#               [
#                 118.504581,
#                 9.316383
#               ]
#             ]
#           ],
#           [
#             [
#               [
#                 122.336957,
#                 18.224883
#               ],
#               [
#                 122.174279,
#                 17.810283
#               ],
#               [
#                 122.515654,
#                 17.093505
#               ],
#               [
#                 122.252311,
#                 16.262444
#               ],
#               [
#                 121.662786,
#                 15.931018
#               ],
#               [
#                 121.50507,
#                 15.124814
#               ],
#               [
#                 121.728829,
#                 14.328376
#               ],
#               [
#                 122.258925,
#                 14.218202
#               ],
#               [
#                 122.701276,
#                 14.336541
#               ],
#               [
#                 123.950295,
#                 13.782131
#               ],
#               [
#                 123.855107,
#                 13.237771
#               ],
#               [
#                 124.181289,
#                 12.997527
#               ],
#               [
#                 124.077419,
#                 12.536677
#               ],
#               [
#                 123.298035,
#                 13.027526
#               ],
#               [
#                 122.928652,
#                 13.55292
#               ],
#               [
#                 122.671355,
#                 13.185836
#               ],
#               [
#                 122.03465,
#                 13.784482
#               ],
#               [
#                 121.126385,
#                 13.636687
#               ],
#               [
#                 120.628637,
#                 13.857656
#               ],
#               [
#                 120.679384,
#                 14.271016
#               ],
#               [
#                 120.991819,
#                 14.525393
#               ],
#               [
#                 120.693336,
#                 14.756671
#               ],
#               [
#                 120.564145,
#                 14.396279
#               ],
#               [
#                 120.070429,
#                 14.970869
#               ],
#               [
#                 119.920929,
#                 15.406347
#               ],
#               [
#                 119.883773,
#                 16.363704
#               ],
#               [
#                 120.286488,
#                 16.034629
#               ],
#               [
#                 120.390047,
#                 17.599081
#               ],
#               [
#                 120.715867,
#                 18.505227
#               ],
#               [
#                 121.321308,
#                 18.504065
#               ],
#               [
#                 121.937601,
#                 18.218552
#               ],
#               [
#                 122.246006,
#                 18.47895
#               ],
#               [
#                 122.336957,
#                 18.224883
#               ]
#             ]
#           ],
#           [
#             [
#               [
#                 122.03837,
#                 11.415841
#               ],
#               [
#                 121.883548,
#                 11.891755
#               ],
#               [
#                 122.483821,
#                 11.582187
#               ],
#               [
#                 123.120217,
#                 11.58366
#               ],
#               [
#                 123.100838,
#                 11.165934
#               ],
#               [
#                 122.637714,
#                 10.741308
#               ],
#               [
#                 122.00261,
#                 10.441017
#               ],
#               [
#                 121.967367,
#                 10.905691
#               ],
#               [
#                 122.03837,
#                 11.415841
#               ]
#             ]
#           ],
#           [
#             [
#               [
#                 125.502552,
#                 12.162695
#               ],
#               [
#                 125.783465,
#                 11.046122
#               ],
#               [
#                 125.011884,
#                 11.311455
#               ],
#               [
#                 125.032761,
#                 10.975816
#               ],
#               [
#                 125.277449,
#                 10.358722
#               ],
#               [
#                 124.801819,
#                 10.134679
#               ],
#               [
#                 124.760168,
#                 10.837995
#               ],
#               [
#                 124.459101,
#                 10.88993
#               ],
#               [
#                 124.302522,
#                 11.495371
#               ],
#               [
#                 124.891013,
#                 11.415583
#               ],
#               [
#                 124.87799,
#                 11.79419
#               ],
#               [
#                 124.266762,
#                 12.557761
#               ],
#               [
#                 125.227116,
#                 12.535721
#               ],
#               [
#                 125.502552,
#                 12.162695
#               ]
#             ]
#           ]
#         ]
#       },
#       "properties": {
#         "name": "Philippines",
#         "value": 4.446414786897268
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               -92.22775,
#               14.538829
#             ],
#             [
#               -92.20323,
#               14.830103
#             ],
#             [
#               -92.087216,
#               15.064585
#             ],
#             [
#               -92.229249,
#               15.251447
#             ],
#             [
#               -91.74796,
#               16.066565
#             ],
#             [
#               -90.464473,
#               16.069562
#             ],
#             [
#               -90.438867,
#               16.41011
#             ],
#             [
#               -90.600847,
#               16.470778
#             ],
#             [
#               -90.711822,
#               16.687483
#             ],
#             [
#               -91.08167,
#               16.918477
#             ],
#             [
#               -91.453921,
#               17.252177
#             ],
#             [
#               -91.002269,
#               17.254658
#             ],
#             [
#               -91.00152,
#               17.817595
#             ],
#             [
#               -90.067934,
#               17.819326
#             ],
#             [
#               -89.14308,
#               17.808319
#             ],
#             [
#               -89.150806,
#               17.015577
#             ],
#             [
#               -89.229122,
#               15.886938
#             ],
#             [
#               -88.930613,
#               15.887273
#             ],
#             [
#               -88.604586,
#               15.70638
#             ],
#             [
#               -88.518364,
#               15.855389
#             ],
#             [
#               -88.225023,
#               15.727722
#             ],
#             [
#               -88.68068,
#               15.346247
#             ],
#             [
#               -89.154811,
#               15.066419
#             ],
#             [
#               -89.22522,
#               14.874286
#             ],
#             [
#               -89.145535,
#               14.678019
#             ],
#             [
#               -89.353326,
#               14.424133
#             ],
#             [
#               -89.587343,
#               14.362586
#             ],
#             [
#               -89.534219,
#               14.244816
#             ],
#             [
#               -89.721934,
#               14.134228
#             ],
#             [
#               -90.064678,
#               13.88197
#             ],
#             [
#               -90.095555,
#               13.735338
#             ],
#             [
#               -90.608624,
#               13.909771
#             ],
#             [
#               -91.23241,
#               13.927832
#             ],
#             [
#               -91.689747,
#               14.126218
#             ],
#             [
#               -92.22775,
#               14.538829
#             ]
#           ]
#         ]
#       },
#       "properties": {
#         "name": "Guatemala",
#         "value": 3.684249650834931
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "MultiPolygon",
#         "coordinates": [
#           [
#             [
#               [
#                 26.290003,
#                 35.29999
#               ],
#               [
#                 26.164998,
#                 35.004995
#               ],
#               [
#                 24.724982,
#                 34.919988
#               ],
#               [
#                 24.735007,
#                 35.084991
#               ],
#               [
#                 23.514978,
#                 35.279992
#               ],
#               [
#                 23.69998,
#                 35.705004
#               ],
#               [
#                 24.246665,
#                 35.368022
#               ],
#               [
#                 25.025015,
#                 35.424996
#               ],
#               [
#                 25.769208,
#                 35.354018
#               ],
#               [
#                 25.745023,
#                 35.179998
#               ],
#               [
#                 26.290003,
#                 35.29999
#               ]
#             ]
#           ],
#           [
#             [
#               [
#                 22.952377,
#                 41.337994
#               ],
#               [
#                 23.692074,
#                 41.309081
#               ],
#               [
#                 24.492645,
#                 41.583896
#               ],
#               [
#                 25.197201,
#                 41.234486
#               ],
#               [
#                 26.106138,
#                 41.328899
#               ],
#               [
#                 26.117042,
#                 41.826905
#               ],
#               [
#                 26.604196,
#                 41.562115
#               ],
#               [
#                 26.294602,
#                 40.936261
#               ],
#               [
#                 26.056942,
#                 40.824123
#               ],
#               [
#                 25.447677,
#                 40.852545
#               ],
#               [
#                 24.925848,
#                 40.947062
#               ],
#               [
#                 23.714811,
#                 40.687129
#               ],
#               [
#                 24.407999,
#                 40.124993
#               ],
#               [
#                 23.899968,
#                 39.962006
#               ],
#               [
#                 23.342999,
#                 39.960998
#               ],
#               [
#                 22.813988,
#                 40.476005
#               ],
#               [
#                 22.626299,
#                 40.256561
#               ],
#               [
#                 22.849748,
#                 39.659311
#               ],
#               [
#                 23.350027,
#                 39.190011
#               ],
#               [
#                 22.973099,
#                 38.970903
#               ],
#               [
#                 23.530016,
#                 38.510001
#               ],
#               [
#                 24.025025,
#                 38.219993
#               ],
#               [
#                 24.040011,
#                 37.655015
#               ],
#               [
#                 23.115003,
#                 37.920011
#               ],
#               [
#                 23.409972,
#                 37.409991
#               ],
#               [
#                 22.774972,
#                 37.30501
#               ],
#               [
#                 23.154225,
#                 36.422506
#               ],
#               [
#                 22.490028,
#                 36.41
#               ],
#               [
#                 21.670026,
#                 36.844986
#               ],
#               [
#                 21.295011,
#                 37.644989
#               ],
#               [
#                 21.120034,
#                 38.310323
#               ],
#               [
#                 20.730032,
#                 38.769985
#               ],
#               [
#                 20.217712,
#                 39.340235
#               ],
#               [
#                 20.150016,
#                 39.624998
#               ],
#               [
#                 20.615,
#                 40.110007
#               ],
#               [
#                 20.674997,
#                 40.435
#               ],
#               [
#                 20.99999,
#                 40.580004
#               ],
#               [
#                 21.02004,
#                 40.842727
#               ],
#               [
#                 21.674161,
#                 40.931275
#               ],
#               [
#                 22.055378,
#                 41.149866
#               ],
#               [
#                 22.597308,
#                 41.130487
#               ],
#               [
#                 22.76177,
#                 41.3048
#               ],
#               [
#                 22.952377,
#                 41.337994
#               ]
#             ]
#           ]
#         ]
#       },
#       "properties": {
#         "name": "Greece",
#         "value": 3.492436682631141
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "MultiPolygon",
#         "coordinates": [
#           [
#             [
#               [
#                 -68.63401,
#                 -52.63637
#               ],
#               [
#                 -68.63335,
#                 -54.8695
#               ],
#               [
#                 -67.56244,
#                 -54.87001
#               ],
#               [
#                 -66.95992,
#                 -54.89681
#               ],
#               [
#                 -67.29103,
#                 -55.30124
#               ],
#               [
#                 -68.14863,
#                 -55.61183
#               ],
#               [
#                 -68.639991,
#                 -55.580018
#               ],
#               [
#                 -69.2321,
#                 -55.49906
#               ],
#               [
#                 -69.95809,
#                 -55.19843
#               ],
#               [
#                 -71.00568,
#                 -55.05383
#               ],
#               [
#                 -72.2639,
#                 -54.49514
#               ],
#               [
#                 -73.2852,
#                 -53.95752
#               ],
#               [
#                 -74.66253,
#                 -52.83749
#               ],
#               [
#                 -73.8381,
#                 -53.04743
#               ],
#               [
#                 -72.43418,
#                 -53.7154
#               ],
#               [
#                 -71.10773,
#                 -54.07433
#               ],
#               [
#                 -70.59178,
#                 -53.61583
#               ],
#               [
#                 -70.26748,
#                 -52.93123
#               ],
#               [
#                 -69.34565,
#                 -52.5183
#               ],
#               [
#                 -68.63401,
#                 -52.63637
#               ]
#             ]
#           ],
#           [
#             [
#               [
#                 -69.590424,
#                 -17.580012
#               ],
#               [
#                 -69.100247,
#                 -18.260125
#               ],
#               [
#                 -68.966818,
#                 -18.981683
#               ],
#               [
#                 -68.442225,
#                 -19.405068
#               ],
#               [
#                 -68.757167,
#                 -20.372658
#               ],
#               [
#                 -68.219913,
#                 -21.494347
#               ],
#               [
#                 -67.82818,
#                 -22.872919
#               ],
#               [
#                 -67.106674,
#                 -22.735925
#               ],
#               [
#                 -66.985234,
#                 -22.986349
#               ],
#               [
#                 -67.328443,
#                 -24.025303
#               ],
#               [
#                 -68.417653,
#                 -24.518555
#               ],
#               [
#                 -68.386001,
#                 -26.185016
#               ],
#               [
#                 -68.5948,
#                 -26.506909
#               ],
#               [
#                 -68.295542,
#                 -26.89934
#               ],
#               [
#                 -69.001235,
#                 -27.521214
#               ],
#               [
#                 -69.65613,
#                 -28.459141
#               ],
#               [
#                 -70.01355,
#                 -29.367923
#               ],
#               [
#                 -69.919008,
#                 -30.336339
#               ],
#               [
#                 -70.535069,
#                 -31.36501
#               ],
#               [
#                 -70.074399,
#                 -33.09121
#               ],
#               [
#                 -69.814777,
#                 -33.273886
#               ],
#               [
#                 -69.817309,
#                 -34.193571
#               ],
#               [
#                 -70.388049,
#                 -35.169688
#               ],
#               [
#                 -70.364769,
#                 -36.005089
#               ],
#               [
#                 -71.121881,
#                 -36.658124
#               ],
#               [
#                 -71.118625,
#                 -37.576827
#               ],
#               [
#                 -70.814664,
#                 -38.552995
#               ],
#               [
#                 -71.413517,
#                 -38.916022
#               ],
#               [
#                 -71.680761,
#                 -39.808164
#               ],
#               [
#                 -71.915734,
#                 -40.832339
#               ],
#               [
#                 -71.746804,
#                 -42.051386
#               ],
#               [
#                 -72.148898,
#                 -42.254888
#               ],
#               [
#                 -71.915424,
#                 -43.408565
#               ],
#               [
#                 -71.464056,
#                 -43.787611
#               ],
#               [
#                 -71.793623,
#                 -44.207172
#               ],
#               [
#                 -71.329801,
#                 -44.407522
#               ],
#               [
#                 -71.222779,
#                 -44.784243
#               ],
#               [
#                 -71.659316,
#                 -44.973689
#               ],
#               [
#                 -71.552009,
#                 -45.560733
#               ],
#               [
#                 -71.917258,
#                 -46.884838
#               ],
#               [
#                 -72.447355,
#                 -47.738533
#               ],
#               [
#                 -72.331161,
#                 -48.244238
#               ],
#               [
#                 -72.648247,
#                 -48.878618
#               ],
#               [
#                 -73.415436,
#                 -49.318436
#               ],
#               [
#                 -73.328051,
#                 -50.378785
#               ],
#               [
#                 -72.975747,
#                 -50.74145
#               ],
#               [
#                 -72.309974,
#                 -50.67701
#               ],
#               [
#                 -72.329404,
#                 -51.425956
#               ],
#               [
#                 -71.914804,
#                 -52.009022
#               ],
#               [
#                 -69.498362,
#                 -52.142761
#               ],
#               [
#                 -68.571545,
#                 -52.299444
#               ],
#               [
#                 -69.461284,
#                 -52.291951
#               ],
#               [
#                 -69.94278,
#                 -52.537931
#               ],
#               [
#                 -70.845102,
#                 -52.899201
#               ],
#               [
#                 -71.006332,
#                 -53.833252
#               ],
#               [
#                 -71.429795,
#                 -53.856455
#               ],
#               [
#                 -72.557943,
#                 -53.53141
#               ],
#               [
#                 -73.702757,
#                 -52.835069
#               ],
#               [
#                 -73.702757,
#                 -52.83507
#               ],
#               [
#                 -74.946763,
#                 -52.262754
#               ],
#               [
#                 -75.260026,
#                 -51.629355
#               ],
#               [
#                 -74.976632,
#                 -51.043396
#               ],
#               [
#                 -75.479754,
#                 -50.378372
#               ],
#               [
#                 -75.608015,
#                 -48.673773
#               ],
#               [
#                 -75.18277,
#                 -47.711919
#               ],
#               [
#                 -74.126581,
#                 -46.939253
#               ],
#               [
#                 -75.644395,
#                 -46.647643
#               ],
#               [
#                 -74.692154,
#                 -45.763976
#               ],
#               [
#                 -74.351709,
#                 -44.103044
#               ],
#               [
#                 -73.240356,
#                 -44.454961
#               ],
#               [
#                 -72.717804,
#                 -42.383356
#               ],
#               [
#                 -73.3889,
#                 -42.117532
#               ],
#               [
#                 -73.701336,
#                 -43.365776
#               ],
#               [
#                 -74.331943,
#                 -43.224958
#               ],
#               [
#                 -74.017957,
#                 -41.794813
#               ],
#               [
#                 -73.677099,
#                 -39.942213
#               ],
#               [
#                 -73.217593,
#                 -39.258689
#               ],
#               [
#                 -73.505559,
#                 -38.282883
#               ],
#               [
#                 -73.588061,
#                 -37.156285
#               ],
#               [
#                 -73.166717,
#                 -37.12378
#               ],
#               [
#                 -72.553137,
#                 -35.50884
#               ],
#               [
#                 -71.861732,
#                 -33.909093
#               ],
#               [
#                 -71.43845,
#                 -32.418899
#               ],
#               [
#                 -71.668721,
#                 -30.920645
#               ],
#               [
#                 -71.370083,
#                 -30.095682
#               ],
#               [
#                 -71.489894,
#                 -28.861442
#               ],
#               [
#                 -70.905124,
#                 -27.64038
#               ],
#               [
#                 -70.724954,
#                 -25.705924
#               ],
#               [
#                 -70.403966,
#                 -23.628997
#               ],
#               [
#                 -70.091246,
#                 -21.393319
#               ],
#               [
#                 -70.16442,
#                 -19.756468
#               ],
#               [
#                 -70.372572,
#                 -18.347975
#               ],
#               [
#                 -69.858444,
#                 -18.092694
#               ],
#               [
#                 -69.590424,
#                 -17.580012
#               ]
#             ]
#           ]
#         ]
#       },
#       "properties": {
#         "name": "Chile",
#         "value": 2.8552117139762077
#       }
#     }
#   ]
# }

# %%
import folium
import json

geojson_data = json.loads(geojson_output)

m = folium.Map(location=[0, 0], zoom_start=2)  # default map

# Add the GeoJSON data to the map
folium.GeoJson(geojson_data).add_to(m)

# Get bounds from GeoJSON data and fit the map to those bounds
# Extract bounds from geojson_data
bounds = folium.GeoJson(geojson_data).get_bounds()
# Ensure bounds are valid before fitting
if bounds:
    m.fit_bounds(bounds)

# Display the map
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_05b9d48d11903735e918b6fc7a7c372a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_05b9d48d11903735e918b6fc7a7c372a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_05b9d48d11903735e918b6fc7a7c372a = L.map(
#                 &quot;map_05b9d48d11903735e918b6fc7a7c372a&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_03680a99e857a535ab671ce6bf10e71e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_03680a99e857a535ab671ce6bf10e71e.addTo(map_05b9d48d11903735e918b6fc7a7c372a);
#
#
#
#         function geo_json_e85e70e0d5a5941d3d1e267206d9a6fe_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_e85e70e0d5a5941d3d1e267206d9a6fe = L.geoJson(null, {
#                 onEachFeature: geo_json_e85e70e0d5a5941d3d1e267206d9a6fe_onEachFeature,
#
#         });
#
#         function geo_json_e85e70e0d5a5941d3d1e267206d9a6fe_add (data) {
#             geo_json_e85e70e0d5a5941d3d1e267206d9a6fe
#                 .addData(data);
#         }
#             geo_json_e85e70e0d5a5941d3d1e267206d9a6fe_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[121.777818, 24.394274], [121.175632, 22.790857], [120.74708, 21.970571], [120.220083, 22.814861], [120.106189, 23.556263], [120.69468, 24.538451], [121.495044, 25.295459], [121.951244, 24.997596], [121.777818, 24.394274]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;Taiwan&quot;, &quot;value&quot;: 23.987808024994848}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[167.216801, -15.891846], [167.844877, -16.466333], [167.515181, -16.59785], [167.180008, -16.159995], [167.216801, -15.891846]]], [[[166.793158, -15.668811], [166.649859, -15.392704], [166.629137, -14.626497], [167.107712, -14.93392], [167.270028, -15.740021], [167.001207, -15.614602], [166.793158, -15.668811]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;Vanuatu&quot;, &quot;value&quot;: 22.17553234756614}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[162.119025, -10.482719], [162.398646, -10.826367], [161.700032, -10.820011], [161.319797, -10.204751], [161.917383, -10.446701], [162.119025, -10.482719]]], [[[161.679982, -9.599982], [161.529397, -9.784312], [160.788253, -8.917543], [160.579997, -8.320009], [160.920028, -8.320009], [161.280006, -9.120011], [161.679982, -9.599982]]], [[[160.852229, -9.872937], [160.462588, -9.89521], [159.849447, -9.794027], [159.640003, -9.63998], [159.702945, -9.24295], [160.362956, -9.400304], [160.688518, -9.610162], [160.852229, -9.872937]]], [[[159.640003, -8.020027], [159.875027, -8.33732], [159.917402, -8.53829], [159.133677, -8.114181], [158.586114, -7.754824], [158.21115, -7.421872], [158.359978, -7.320018], [158.820001, -7.560003], [159.640003, -8.020027]]], [[[157.14, -7.021638], [157.538426, -7.34782], [157.33942, -7.404767], [156.90203, -7.176874], [156.491358, -6.765943], [156.542828, -6.599338], [157.14, -7.021638]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;Solomon Is.&quot;, &quot;value&quot;: 11.31540688439896}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-82.546196, 9.566135], [-82.932891, 9.476812], [-82.927155, 9.07433], [-82.719183, 8.925709], [-82.868657, 8.807266], [-82.829771, 8.626295], [-82.913176, 8.423517], [-82.965783, 8.225028], [-83.508437, 8.446927], [-83.711474, 8.656836], [-83.596313, 8.830443], [-83.632642, 9.051386], [-83.909886, 9.290803], [-84.303402, 9.487354], [-84.647644, 9.615537], [-84.713351, 9.908052], [-84.97566, 10.086723], [-84.911375, 9.795992], [-85.110923, 9.55704], [-85.339488, 9.834542], [-85.660787, 9.933347], [-85.797445, 10.134886], [-85.791709, 10.439337], [-85.659314, 10.754331], [-85.941725, 10.895278], [-85.71254, 11.088445], [-85.561852, 11.217119], [-84.903003, 10.952303], [-84.673069, 11.082657], [-84.355931, 10.999226], [-84.190179, 10.79345], [-83.895054, 10.726839], [-83.655612, 10.938764], [-83.40232, 10.395438], [-83.015677, 9.992982], [-82.546196, 9.566135]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;Costa Rica&quot;, &quot;value&quot;: 9.236891343507267}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[141.00021, -2.600151], [142.735247, -3.289153], [144.583971, -3.861418], [145.27318, -4.373738], [145.829786, -4.876498], [145.981922, -5.465609], [147.648073, -6.083659], [147.891108, -6.614015], [146.970905, -6.721657],

# %% [markdown]
# ## DuckDB Spatial

# %% [markdown]
# ### このノートブックの流れ
#
# - 生成 AI に、自然言語から SQL を出力させる
# - 出力された SQL を DuckDB で実行する
# - 実行結果を GeoJSON に変換する
# - GeoJSON を地図上に表示する

# %% [markdown]
# ### 前準備

# %% [markdown]
# ### DuckDB のセットアップとデータの読み込み

# %%
import duckdb

# DuckDBに接続（インメモリで動作）
conn = duckdb.connect()

# DuckDBに拡張機能をインストール
conn.execute("""
INSTALL httpfs;
INSTALL json;
INSTALL spatial;
""")
conn.execute(f"""
LOAD httpfs;
LOAD json;
LOAD spatial;
""")
# NOTE: closeするとDBの内容が失われるのでcloseしてはいけない
# conn.close()
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
# NOTE: connはgeojsonを読み込んだものを使い回す必要がある
# conn = duckdb.connect()

# GeoJSONファイルのURL
# admin_geojson_url = "https://github.com/nvkelso/natural-earth-vector/raw/master/geojson/ne_10m_admin_0_countries.geojson"
admin_geojson_url = "https://github.com/nvkelso/natural-earth-vector/raw/master/geojson/ne_110m_admin_0_countries.geojson"

# GeoJSON を DuckDBにテーブルとして読み込む
conn.execute(f"CREATE TABLE countries AS SELECT * FROM ST_Read('{admin_geojson_url}')")

# NOTE: closeするとDBの内容が失われるのでcloseしてはいけない
# conn.close()

# %% [markdown]
# ### データベースのテーブルスキーマを文字列にする

# %%
# NOTE: connはgeojsonを読み込んだものを使い回す必要がある
# conn = duckdb.connect()
summary_of_tables = ""

# SHOWによってテーブル一覧を取得
show_result = conn.execute("SHOW").fetchall()
tables = [row[2] for row in show_result]

for table in tables:
    summary_of_tables += f"Table: {table}\n"
    # DESCRIBE TABLEの結果を文字列に変換
    describe_result = conn.execute(f"DESCRIBE TABLE {table}").fetchall()
    for row in describe_result:
        field_name = row[0]
        field_type = row[1]
        summary_of_tables += f"  Field: {field_name}, {field_type}\n"
print(summary_of_tables)
# Out:
# Table: countries
#   Field: featurecla, VARCHAR
#   Field: scalerank, INTEGER
#   Field: LABELRANK, INTEGER
#   Field: SOVEREIGNT, VARCHAR
#   Field: SOV_A3, VARCHAR
#   Field: ADM0_DIF, INTEGER
#   Field: LEVEL, INTEGER
#   Field: TYPE, VARCHAR
#   Field: TLC, VARCHAR
#   Field: ADMIN, VARCHAR
#   Field: ADM0_A3, VARCHAR
#   Field: GEOU_DIF, INTEGER
#   Field: GEOUNIT, VARCHAR
#   Field: GU_A3, VARCHAR
#   Field: SU_DIF, INTEGER
#   Field: SUBUNIT, VARCHAR
#   Field: SU_A3, VARCHAR
#   Field: BRK_DIFF, INTEGER
#   Field: NAME, VARCHAR
#   Field: NAME_LONG, VARCHAR
#   Field: BRK_A3, VARCHAR
#   Field: BRK_NAME, VARCHAR
#   Field: BRK_GROUP, VARCHAR
#   Field: ABBREV, VARCHAR
#   Field: POSTAL, VARCHAR
#   Field: FORMAL_EN, VARCHAR
#   Field: FORMAL_FR, VARCHAR
#   Field: NAME_CIAWF, VARCHAR
#   Field: NOTE_ADM0, VARCHAR
#   Field: NOTE_BRK, VARCHAR
#   Field: NAME_SORT, VARCHAR
#   Field: NAME_ALT, VARCHAR
#   Field: MAPCOLOR7, INTEGER
#   Field: MAPCOLOR8, INTEGER
#   Field: MAPCOLOR9, INTEGER
#   Field: MAPCOLOR13, INTEGER
#   Field: POP_EST, DOUBLE
#   Field: POP_RANK, INTEGER
#   Field: POP_YEAR, INTEGER
#   Field: GDP_MD, INTEGER
#   Field: GDP_YEAR, INTEGER
#   Field: ECONOMY, VARCHAR
#   Field: INCOME_GRP, VARCHAR
#   Field: FIPS_10, VARCHAR
#   Field: ISO_A2, VARCHAR
#   Field: ISO_A2_EH, VARCHAR
#   Field: ISO_A3, VARCHAR
#   Field: ISO_A3_EH, VARCHAR
#   Field: ISO_N3, VARCHAR
#   Field: ISO_N3_EH, VARCHAR
#   Field: UN_A3, VARCHAR
#   Field: WB_A2, VARCHAR
#   Field: WB_A3, VARCHAR
#   Field: WOE_ID, INTEGER
#   Field: WOE_ID_EH, INTEGER
#   Field: WOE_NOTE, VARCHAR
#   Field: ADM0_ISO, VARCHAR
#   Field: ADM0_DIFF, VARCHAR
#   Field: ADM0_TLC, VARCHAR
#   Field: ADM0_A3_US, VARCHAR
#   Field: ADM0_A3_FR, VARCHAR
#   Field: ADM0_A3_RU, VARCHAR
#   Field: ADM0_A3_ES, VARCHAR
#   Field: ADM0_A3_CN, VARCHAR
#   Field: ADM0_A3_TW, VARCHAR
#   Field: ADM0_A3_IN, VARCHAR
#   Field: ADM0_A3_NP, VARCHAR
#   Field: ADM0_A3_PK, VARCHAR
#   Field: ADM0_A3_DE, VARCHAR
#   Field: ADM0_A3_GB, VARCHAR
#   Field: ADM0_A3_BR, VARCHAR
#   Field: ADM0_A3_IL, VARCHAR
#   Field: ADM0_A3_PS, VARCHAR
#   Field: ADM0_A3_SA, VARCHAR
#   Field: ADM0_A3_EG, VARCHAR
#   Field: ADM0_A3_MA, VARCHAR
#   Field: ADM0_A3_PT, VARCHAR
#   Field: ADM0_A3_AR, VARCHAR
#   Field: ADM0_A3_JP, VARCHAR
#   Field: ADM0_A3_KO, VARCHAR
#   Field: ADM0_A3_VN, VARCHAR
#   Field: ADM0_A3_TR, VARCHAR
#   Field: ADM0_A3_ID, VARCHAR
#   Field: ADM0_A3_PL, VARCHAR
#   Field: ADM0_A3_GR, VARCHAR
#   Field: ADM0_A3_IT, VARCHAR
#   Field: ADM0_A3_NL, VARCHAR
#   Field: ADM0_A3_SE, VARCHAR
#   Field: ADM0_A3_BD, VARCHAR
#   Field: ADM0_A3_UA, VARCHAR
#   Field: ADM0_A3_UN, INTEGER
#   Field: ADM0_A3_WB, INTEGER
#   Field: CONTINENT, VARCHAR
#   Field: REGION_UN, VARCHAR
#   Field: SUBREGION, VARCHAR
#   Field: REGION_WB, VARCHAR
#   Field: NAME_LEN, INTEGER
#   Field: LONG_LEN, INTEGER
#   Field: ABBREV_LEN, INTEGER
#   Field: TINY, INTEGER
#   Field: HOMEPART, INTEGER
#   Field: MIN_ZOOM, DOUBLE
#   Field: MIN_LABEL, DOUBLE
#   Field: MAX_LABEL, DOUBLE
#   Field: LABEL_X, DOUBLE
#   Field: LABEL_Y, DOUBLE
#   Field: NE_ID, INTEGER
#   Field: WIKIDATAID, VARCHAR
#   Field: NAME_AR, VARCHAR
#   Field: NAME_BN, VARCHAR
#   Field: NAME_DE, VARCHAR
#   Field: NAME_EN, VARCHAR
#   Field: NAME_ES, VARCHAR
#   Field: NAME_FA, VARCHAR
#   Field: NAME_FR, VARCHAR
#   Field: NAME_EL, VARCHAR
#   Field: NAME_HE, VARCHAR
#   Field: NAME_HI, VARCHAR
#   Field: NAME_HU, VARCHAR
#   Field: NAME_ID, VARCHAR
#   Field: NAME_IT, VARCHAR
#   Field: NAME_JA, VARCHAR
#   Field: NAME_KO, VARCHAR
#   Field: NAME_NL, VARCHAR
#   Field: NAME_PL, VARCHAR
#   Field: NAME_PT, VARCHAR
#   Field: NAME_RU, VARCHAR
#   Field: NAME_SV, VARCHAR
#   Field: NAME_TR, VARCHAR
#   Field: NAME_UK, VARCHAR
#   Field: NAME_UR, VARCHAR
#   Field: NAME_VI, VARCHAR
#   Field: NAME_ZH, VARCHAR
#   Field: NAME_ZHT, VARCHAR
#   Field: FCLASS_ISO, VARCHAR
#   Field: TLC_DIFF, VARCHAR
#   Field: FCLASS_TLC, VARCHAR
#   Field: FCLASS_US, VARCHAR
#   Field: FCLASS_FR, VARCHAR
#   Field: FCLASS_RU, VARCHAR
#   Field: FCLASS_ES, VARCHAR
#   Field: FCLASS_CN, VARCHAR
#   Field: FCLASS_TW, VARCHAR
#   Field: FCLASS_IN, VARCHAR
#   Field: FCLASS_NP, VARCHAR
#   Field: FCLASS_PK, VARCHAR
#   Field: FCLASS_DE, VARCHAR
#   Field: FCLASS_GB, VARCHAR
#   Field: FCLASS_BR, VARCHAR
#   Field: FCLASS_IL, VARCHAR
#   Field: FCLASS_PS, VARCHAR
#   Field: FCLASS_SA, VARCHAR
#   Field: FCLASS_EG, VARCHAR
#   Field: FCLASS_MA, VARCHAR
#   Field: FCLASS_PT, VARCHAR
#   Field: FCLASS_AR, VARCHAR
#   Field: FCLASS_JP, VARCHAR
#   Field: FCLASS_KO, VARCHAR
#   Field: FCLASS_VN, VARCHAR
#   Field: FCLASS_TR, VARCHAR
#   Field: FCLASS_ID, VARCHAR
#   Field: FCLASS_PL, VARCHAR
#   Field: FCLASS_GR, VARCHAR
#   Field: FCLASS_IT, VARCHAR
#   Field: FCLASS_NL, VARCHAR
#   Field: FCLASS_SE, VARCHAR
#   Field: FCLASS_BD, VARCHAR
#   Field: FCLASS_UA, VARCHAR
#   Field: geom, GEOMETRY

# %% [markdown]
# ### 対象となる自然言語

# %%
input_text = "日本よりも人口密度が高い国は？"
print(input_text)
# Out:
# 日本よりも人口密度が高い国は？

# %% [markdown]
# ### 生成 AI にスキーマと自然言語から SQL を出力させる

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI

# モデルの準備
model = ChatGoogleGenerativeAI(model="gemini-exp-1206", temperature=0)

# プロンプトの準備
template = """You are an expert of PostgreSQL and PostGIS.
You output the best PostgreSQL query based on given table schema and input text.

You will always reply according to the following rules:
- Output valid PostgreSQL query.
- The query MUST be return name, value and geom columns. Use AS to rename columns.
- The query MUST use ST_AsGeoJSON function to output geom column.
- The query MUST be line delimited and surrounded by just three backquote to indicate that it is a code block.
- The Value column should be a value that takes into account the user's intent to the greatest extent possible.

** Table Schema: **
{table_schema}

User Input:
{input}
"""
prompt = ChatPromptTemplate.from_template(template)

chain = prompt | model

res = chain.invoke({"input": input_text, "table_schema": summary_of_tables})
result = res.content.strip()
print(result)
# Out:
# ```sql
# SELECT
#   NAME AS name,
#   POP_EST / ST_Area(geom) AS value,
#   ST_AsGeoJSON(geom) AS geom
# FROM
#   countries
# WHERE
#   POP_EST / ST_Area(geom) > (
#     SELECT
#       POP_EST / ST_Area(geom)
#     FROM
#       countries
#     WHERE
#       NAME = 'Japan'
#   );
# ```

# %%
import re
match = re.search(r"```[^\n]*\n(.*?)```", result, re.DOTALL)

if match:
    sql_query = match.group(1).strip()
    print(sql_query)
else:
    print("SQLが見つかりませんでした。")
# Out:
# SELECT
#   NAME AS name,
#   POP_EST / ST_Area(geom) AS value,
#   ST_AsGeoJSON(geom) AS geom
# FROM
#   countries
# WHERE
#   POP_EST / ST_Area(geom) > (
#     SELECT
#       POP_EST / ST_Area(geom)
#     FROM
#       countries
#     WHERE
#       NAME = 'Japan'
#   );

# %% [markdown]
# ### 出力された SQL を DuckDB で実行する

# %%
duckdb_result = conn.execute(sql_query).fetchall()
duckdb_result
# Out:
# [('Haiti',
#   4602594.646601417,
#   '{"type":"Polygon","coordinates":[[[-71.712361,19.714456],[-71.624873,19.169838],[-71.701303,18.785417],[-71.945112,18.6169],[-71.687738,18.31666],[-71.708305,18.044997],[-72.372476,18.214961],[-72.844411,18.145611],[-73.454555,18.217906],[-73.922433,18.030993],[-74.458034,18.34255],[-74.369925,18.664908],[-73.449542,18.526053],[-72.694937,18.445799],[-72.334882,18.668422],[-72.79165,19.101625],[-72.784105,19.483591],[-73.415022,19.639551],[-73.189791,19.915684],[-72.579673,19.871501],[-71.712361,19.714456]]]}'),
#  ('El Salvador',
#   3696006.632444857,
#   '{"type":"Polygon","coordinates":[[[-89.353326,14.424133],[-89.058512,14.340029],[-88.843073,14.140507],[-88.541231,13.980155],[-88.503998,13.845486],[-88.065343,13.964626],[-87.859515,13.893312],[-87.723503,13.78505],[-87.793111,13.38448],[-87.904112,13.149017],[-88.483302,13.163951],[-88.843228,13.259734],[-89.256743,13.458533],[-89.812394,13.520622],[-90.095555,13.735338],[-90.064678,13.88197],[-89.721934,14.134228],[-89.534219,14.244816],[-89.587343,14.362586],[-89.353326,14.424133]]]}'),
#  ('Puerto Rico',
#   4052864.9406663175,
#   '{"type":"Polygon","coordinates":[[[-66.282434,18.514762],[-65.771303,18.426679],[-65.591004,18.228035],[-65.847164,17.975906],[-66.599934,17.981823],[-67.184162,17.946553],[-67.242428,18.37446],[-67.100679,18.520601],[-66.282434,18.514762]]]}'),
#  ('Burundi',
#   5399902.326990314,
#   '{"type":"Polygon","coordinates":[[[30.469674,-2.413855],[30.52766,-2.80762],[30.74301,-3.03431],[30.75224,-3.35931],[30.50554,-3.56858],[30.11632,-4.09012],[29.753512,-4.452389],[29.339998,-4.499983],[29.276384,-3.293907],[29.024926,-2.839258],[29.632176,-2.917858],[29.938359,-2.348487],[30.469674,-2.413855]]]}'),
#  ('Israel',
#   4140048.5897242688,
#   '{"type":"Polygon","coordinates":[[[35.719918,32.709192],[35.545665,32.393992],[35.18393,32.532511],[34.974641,31.866582],[35.225892,31.754341],[34.970507,31.616778],[34.927408,31.353435],[35.397561,31.489086],[35.420918,31.100066],[34.922603,29.501326],[34.823243,29.761081],[34.26544,31.21936],[34.265435,31.219357],[34.265433,31.219361],[34.556372,31.548824],[34.488107,31.605539],[34.752587,32.072926],[34.955417,32.827376],[35.098457,33.080539],[35.126053,33.0909],[35.460709,33.08904],[35.552797,33.264275],[35.821101,33.277426],[35.836397,32.868123],[35.700798,32.716014],[35.719918,32.709192]]]}'),
#  ('Lebanon',
#   6968537.550483227,
#   '{"type":"Polygon","coordinates":[[[35.821101,33.277426],[35.552797,33.264275],[35.460709,33.08904],[35.126053,33.0909],[35.482207,33.90545],[35.979592,34.610058],[35.998403,34.644914],[36.448194,34.593935],[36.61175,34.201789],[36.06646,33.824912],[35.821101,33.277426]]]}'),
#  ('Palestine',
#   9754682.799512533,
#   '{"type":"Polygon","coordinates":[[[35.397561,31.489086],[34.927408,31.353435],[34.970507,31.616778],[35.225892,31.754341],[34.974641,31.866582],[35.18393,32.532511],[35.545665,32.393992],[35.545252,31.782505],[35.397561,31.489086]]]}'),
#  ('Vietnam',
#   3378396.377624047,
#   '{"type":"Polygon","coordinates":[[[104.334335,10.486544],[105.199915,10.88931],[106.24967,10.961812],[105.810524,11.567615],[107.491403,12.337206],[107.614548,13.535531],[107.382727,14.202441],[107.564525,15.202173],[107.312706,15.908538],[106.556008,16.604284],[105.925762,17.485315],[105.094598,18.666975],[103.896532,19.265181],[104.183388,19.624668],[104.822574,19.886642],[104.435,20.758733],[103.203861,20.766562],[102.754896,21.675137],[102.170436,22.464753],[102.706992,22.708795],[103.504515,22.703757],[104.476858,22.81915],[105.329209,23.352063],[105.811247,22.976892],[106.725403,22.794268],[106.567273,22.218205],[107.04342,21.811899],[108.05018,21.55238],[106.715068,20.696851],[105.881682,19.75205],[105.662006,19.058165],[106.426817,18.004121],[107.361954,16.697457],[108.269495,16.079742],[108.877107,15.276691],[109.33527,13.426028],[109.200136,11.666859],[108.36613,11.008321],[107.220929,10.364484],[106.405113,9.53084],[105.158264,8.59976],[104.795185,9.241038],[105.076202,9.918491],[104.334335,10.486544]]]}'),
#  ('South Korea',
#   5194378.260938433,
#   '{"type":"Polygon","coordinates":[[[126.174759,37.749686],[126.237339,37.840378],[126.68372,37.804773],[127.073309,38.256115],[127.780035,38.304536],[128.205746,38.370397],[128.349716,38.612243],[129.21292,37.432392],[129.46045,36.784189],[129.468304,35.632141],[129.091377,35.082484],[128.18585,34.890377],[127.386519,34.475674],[126.485748,34.390046],[126.37392,34.93456],[126.559231,35.684541],[126.117398,36.725485],[126.860143,36.893924],[126.174759,37.749686]]]}'),
#  ('India',
#   4916503.213323983,
#   '{"type":"Polygon","coordinates":[[[97.327114,28.261583],[97.402561,27.882536],[97.051989,27.699059],[97.133999,27.083774],[96.419366,27.264589],[95.124768,26.573572],[95.155153,26.001307],[94.603249,25.162495],[94.552658,24.675238],[94.106742,23.850741],[93.325188,24.078556],[93.286327,23.043658],[93.060294,22.703111],[93.166128,22.27846],[92.672721,22.041239],[92.146035,23.627499],[91.869928,23.624346],[91.706475,22.985264],[91.158963,23.503527],[91.46773,24.072639],[91.915093,24.130414],[92.376202,24.976693],[91.799596,25.147432],[90.872211,25.132601],[89.920693,25.26975],[89.832481,25.965082],[89.355094,26.014407],[88.563049,26.446526],[88.209789,25.768066],[88.931554,25.238692],[88.306373,24.866079],[88.084422,24.501657],[88.69994,24.233715],[88.52977,23.631142],[88.876312,22.879146],[89.031961,22.055708],[88.888766,21.690588],[88.208497,21.703172],[86.975704,21.495562],[87.033169,20.743308],[86.499351,20.151638],[85.060266,19.478579],[83.941006,18.30201],[83.189217,17.671221],[82.192792,17.016636],[82.191242,16.556664],[81.692719,16.310219],[80.791999,15.951972],[80.324896,15.899185],[80.025069,15.136415],[80.233274,13.835771],[80.286294,13.006261],[79.862547,12.056215],[79.857999,10.357275],[79.340512,10.308854],[78.885345,9.546136],[79.18972,9.216544],[78.277941,8.933047],[77.941165,8.252959],[77.539898,7.965535],[76.592979,8.899276],[76.130061,10.29963],[75.746467,11.308251],[75.396101,11.781245],[74.864816,12.741936],[74.616717,13.992583],[74.443859,14.617222],[73.534199,15.990652],[73.119909,17.92857],[72.820909,19.208234],[72.824475,20.419503],[72.630533,21.356009],[71.175273,20.757441],[70.470459,20.877331],[69.16413,22.089298],[69.644928,22.450775],[69.349597,22.84318],[68.176645,23.691965],[68.842599,24.359134],[71.04324,24.356524],[70.844699,25.215102],[70.282873,25.722229],[70.168927,26.491872],[69.514393,26.940966],[70.616496,27.989196],[71.777666,27.91318],[72.823752,28.961592],[73.450638,29.976413],[74.42138,30.979815],[74.405929,31.692639],[75.258642,32.271105],[74.451559,32.7649],[74.104294,33.441473],[73.749948,34.317699],[74.240203,34.748887],[75.757061,34.504923],[76.871722,34.653544],[77.837451,35.49401],[78.912269,34.321936],[78.811086,33.506198],[79.208892,32.994395],[79.176129,32.48378],[78.458446,32.618164],[78.738894,31.515906],[79.721367,30.882715],[81.111256,30.183481],[80.476721,29.729865],[80.088425,28.79447],[81.057203,28.416095],[81.999987,27.925479],[83.304249,27.364506],[84.675018,27.234901],[85.251779,26.726198],[86.024393,26.630985],[87.227472,26.397898],[88.060238,26.414615],[88.174804,26.810405],[88.043133,27.445819],[88.120441,27.876542],[88.730326,28.086865],[88.814248,27.299316],[88.835643,27.098966],[89.744528,26.719403],[90.373275,26.875724],[91.217513,26.808648],[92.033484,26.83831],[92.103712,27.452614],[91.696657,27.771742],[92.503119,27.896876],[93.413348,28.640629],[94.56599,29.277438],[95.404802,29.031717],[96.117679,29.452802],[96.586591,28.83098],[96.248833,28.411031],[97.327114,28.261583]]]}'),
#  ('Bangladesh',
#   13750842.585969182,
#   '{"type":"Polygon","coordinates":[[[92.672721,22.041239],[92.652257,21.324048],[92.303234,21.475485],[92.368554,20.670883],[92.082886,21.192195],[92.025215,21.70157],[91.834891,22.182936],[91.417087,22.765019],[90.496006,22.805017],[90.586957,22.392794],[90.272971,21.836368],[89.847467,22.039146],[89.70205,21.857116],[89.418863,21.966179],[89.031961,22.055708],[88.876312,22.879146],[88.52977,23.631142],[88.69994,24.233715],[88.084422,24.501657],[88.306373,24.866079],[88.931554,25.238692],[88.209789,25.768066],[88.563049,26.446526],[89.355094,26.014407],[89.832481,25.965082],[89.920693,25.26975],[90.872211,25.132601],[91.799596,25.147432],[92.376202,24.976693],[91.915093,24.130414],[91.46773,24.072639],[91.158963,23.503527],[91.706475,22.985264],[91.869928,23.624346],[92.146035,23.627499],[92.672721,22.041239]]]}'),
#  ('Netherlands',
#   3292602.3652927773,
#   '{"type":"Polygon","coordinates":[[[6.90514,53.482162],[7.092053,53.144043],[6.84287,52.22844],[6.589397,51.852029],[5.988658,51.851616],[6.156658,50.803721],[5.606976,51.037298],[4.973991,51.475024],[4.047071,51.267259],[3.314971,51.345755],[3.315011,51.345777],[3.830289,51.620545],[4.705997,53.091798],[6.074183,53.510403],[6.90514,53.482162]]]}'),
#  ('Sri Lanka',
#   4069422.297867995,
#   '{"type":"Polygon","coordinates":[[[81.787959,7.523055],[81.637322,6.481775],[81.21802,6.197141],[80.348357,5.96837],[79.872469,6.763463],[79.695167,8.200843],[80.147801,9.824078],[80.838818,9.268427],[81.304319,8.564206],[81.787959,7.523055]]]}'),
#  ('Taiwan',
#   7744571.601705644,
#   '{"type":"Polygon","coordinates":[[[121.777818,24.394274],[121.175632,22.790857],[120.74708,21.970571],[120.220083,22.814861],[120.106189,23.556263],[120.69468,24.538451],[121.495044,25.295459],[121.951244,24.997596],[121.777818,24.394274]]]}'),
#  ('Philippines',
#   4451215.885604435,
#   '{"type":"MultiPolygon","coordinates":[[[[120.833896,12.704496],[120.323436,13.466413],[121.180128,13.429697],[121.527394,13.06959],[121.26219,12.20556],[120.833896,12.704496]]],[[[122.586089,9.981045],[122.837081,10.261157],[122.947411,10.881868],[123.49885,10.940624],[123.337774,10.267384],[124.077936,11.232726],[123.982438,10.278779],[123.623183,9.950091],[123.309921,9.318269],[122.995883,9.022189],[122.380055,9.713361],[122.586089,9.981045]]],[[[126.376814,8.414706],[126.478513,7.750354],[126.537424,7.189381],[126.196773,6.274294],[125.831421,7.293715],[125.363852,6.786485],[125.683161,6.049657],[125.396512,5.581003],[124.219788,6.161355],[123.93872,6.885136],[124.243662,7.36061],[123.610212,7.833527],[123.296071,7.418876],[122.825506,7.457375],[122.085499,6.899424],[121.919928,7.192119],[122.312359,8.034962],[122.942398,8.316237],[123.487688,8.69301],[123.841154,8.240324],[124.60147,8.514158],[124.764612,8.960409],[125.471391,8.986997],[125.412118,9.760335],[126.222714,9.286074],[126.306637,8.782487],[126.376814,8.414706]]],[[[118.504581,9.316383],[117.174275,8.3675],[117.664477,9.066889],[118.386914,9.6845],[118.987342,10.376292],[119.511496,11.369668],[119.689677,10.554291],[119.029458,10.003653],[118.504581,9.316383]]],[[[122.336957,18.224883],[122.174279,17.810283],[122.515654,17.093505],[122.252311,16.262444],[121.662786,15.931018],[121.50507,15.124814],[121.728829,14.328376],[122.258925,14.218202],[122.701276,14.336541],[123.950295,13.782131],[123.855107,13.237771],[124.181289,12.997527],[124.077419,12.536677],[123.298035,13.027526],[122.928652,13.55292],[122.671355,13.185836],[122.03465,13.784482],[121.126385,13.636687],[120.628637,13.857656],[120.679384,14.271016],[120.991819,14.525393],[120.693336,14.756671],[120.564145,14.396279],[120.070429,14.970869],[119.920929,15.406347],[119.883773,16.363704],[120.286488,16.034629],[120.390047,17.599081],[120.715867,18.505227],[121.321308,18.504065],[121.937601,18.218552],[122.246006,18.47895],[122.336957,18.224883]]],[[[122.03837,11.415841],[121.883548,11.891755],[122.483821,11.582187],[123.120217,11.58366],[123.100838,11.165934],[122.637714,10.741308],[122.00261,10.441017],[121.967367,10.905691],[122.03837,11.415841]]],[[[125.502552,12.162695],[125.783465,11.046122],[125.011884,11.311455],[125.032761,10.975816],[125.277449,10.358722],[124.801819,10.134679],[124.760168,10.837995],[124.459101,10.88993],[124.302522,11.495371],[124.891013,11.415583],[124.87799,11.79419],[124.266762,12.557761],[125.227116,12.535721],[125.502552,12.162695]]]]}'),
#  ('Rwanda',
#   6647861.182503427,
#   '{"type":"Polygon","coordinates":[[[30.419105,-1.134659],[30.816135,-1.698914],[30.758309,-2.28725],[30.46967,-2.41383],[30.469674,-2.413855],[29.938359,-2.348487],[29.632176,-2.917858],[29.024926,-2.839258],[29.117479,-2.292211],[29.254835,-2.21511],[29.291887,-1.620056],[29.579466,-1.341313],[29.821519,-1.443322],[30.419105,-1.134659]]]}')]

# %% [markdown]
# ### SQL の実行結果を GeoJSON に変換する

# %%
# duckdb_resultをGeoJSONに変換する

import json

def duckdb_result_to_geojson(duckdb_result):
    """Converts DuckDB query result to GeoJSON format.

    Args:
        duckdb_result: The result of a DuckDB query.  Assumes the query returns
        columns named 'name', 'value', and 'geom' where 'geom' is a GeoJSON
        geometry string.

    Returns:
        A GeoJSON FeatureCollection as a string, or None if the conversion fails.
    """
    geojson = {
        "type": "FeatureCollection",
        "features": []
    }

    for row in duckdb_result:
        try:
            name, value, geom_str = row  # Assuming the columns are in this order
            geom = json.loads(geom_str)  # Parse the geometry string as GeoJSON
            feature = {
                "type": "Feature",
                "geometry": geom,
                "properties": {
                    "name": name,
                    "value": value
                }
            }
            geojson["features"].append(feature)
        except (ValueError, TypeError, IndexError) as e:
            print(f"Error processing row {row}: {e}")
            return None  # Return None if any row fails
        except Exception as e:
            print(f"An unexpected error occurred: {e}")
            return None

    return json.dumps(geojson, indent=2)


# Example usage with the duckdb_result
geojson_output = duckdb_result_to_geojson(duckdb_result)

if geojson_output:
    print(geojson_output)
else:
    print("Failed to convert DuckDB result to GeoJSON.")
# Out:
# {
#   "type": "FeatureCollection",
#   "features": [
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               -71.712361,
#               19.714456
#             ],
#             [
#               -71.624873,
#               19.169838
#             ],
#             [
#               -71.701303,
#               18.785417
#             ],
#             [
#               -71.945112,
#               18.6169
#             ],
#             [
#               -71.687738,
#               18.31666
#             ],
#             [
#               -71.708305,
#               18.044997
#             ],
#             [
#               -72.372476,
#               18.214961
#             ],
#             [
#               -72.844411,
#               18.145611
#             ],
#             [
#               -73.454555,
#               18.217906
#             ],
#             [
#               -73.922433,
#               18.030993
#             ],
#             [
#               -74.458034,
#               18.34255
#             ],
#             [
#               -74.369925,
#               18.664908
#             ],
#             [
#               -73.449542,
#               18.526053
#             ],
#             [
#               -72.694937,
#               18.445799
#             ],
#             [
#               -72.334882,
#               18.668422
#             ],
#             [
#               -72.79165,
#               19.101625
#             ],
#             [
#               -72.784105,
#               19.483591
#             ],
#             [
#               -73.415022,
#               19.639551
#             ],
#             [
#               -73.189791,
#               19.915684
#             ],
#             [
#               -72.579673,
#               19.871501
#             ],
#             [
#               -71.712361,
#               19.714456
#             ]
#           ]
#         ]
#       },
#       "properties": {
#         "name": "Haiti",
#         "value": 4602594.646601417
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               -89.353326,
#               14.424133
#             ],
#             [
#               -89.058512,
#               14.340029
#             ],
#             [
#               -88.843073,
#               14.140507
#             ],
#             [
#               -88.541231,
#               13.980155
#             ],
#             [
#               -88.503998,
#               13.845486
#             ],
#             [
#               -88.065343,
#               13.964626
#             ],
#             [
#               -87.859515,
#               13.893312
#             ],
#             [
#               -87.723503,
#               13.78505
#             ],
#             [
#               -87.793111,
#               13.38448
#             ],
#             [
#               -87.904112,
#               13.149017
#             ],
#             [
#               -88.483302,
#               13.163951
#             ],
#             [
#               -88.843228,
#               13.259734
#             ],
#             [
#               -89.256743,
#               13.458533
#             ],
#             [
#               -89.812394,
#               13.520622
#             ],
#             [
#               -90.095555,
#               13.735338
#             ],
#             [
#               -90.064678,
#               13.88197
#             ],
#             [
#               -89.721934,
#               14.134228
#             ],
#             [
#               -89.534219,
#               14.244816
#             ],
#             [
#               -89.587343,
#               14.362586
#             ],
#             [
#               -89.353326,
#               14.424133
#             ]
#           ]
#         ]
#       },
#       "properties": {
#         "name": "El Salvador",
#         "value": 3696006.632444857
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               -66.282434,
#               18.514762
#             ],
#             [
#               -65.771303,
#               18.426679
#             ],
#             [
#               -65.591004,
#               18.228035
#             ],
#             [
#               -65.847164,
#               17.975906
#             ],
#             [
#               -66.599934,
#               17.981823
#             ],
#             [
#               -67.184162,
#               17.946553
#             ],
#             [
#               -67.242428,
#               18.37446
#             ],
#             [
#               -67.100679,
#               18.520601
#             ],
#             [
#               -66.282434,
#               18.514762
#             ]
#           ]
#         ]
#       },
#       "properties": {
#         "name": "Puerto Rico",
#         "value": 4052864.9406663175
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               30.469674,
#               -2.413855
#             ],
#             [
#               30.52766,
#               -2.80762
#             ],
#             [
#               30.74301,
#               -3.03431
#             ],
#             [
#               30.75224,
#               -3.35931
#             ],
#             [
#               30.50554,
#               -3.56858
#             ],
#             [
#               30.11632,
#               -4.09012
#             ],
#             [
#               29.753512,
#               -4.452389
#             ],
#             [
#               29.339998,
#               -4.499983
#             ],
#             [
#               29.276384,
#               -3.293907
#             ],
#             [
#               29.024926,
#               -2.839258
#             ],
#             [
#               29.632176,
#               -2.917858
#             ],
#             [
#               29.938359,
#               -2.348487
#             ],
#             [
#               30.469674,
#               -2.413855
#             ]
#           ]
#         ]
#       },
#       "properties": {
#         "name": "Burundi",
#         "value": 5399902.326990314
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               35.719918,
#               32.709192
#             ],
#             [
#               35.545665,
#               32.393992
#             ],
#             [
#               35.18393,
#               32.532511
#             ],
#             [
#               34.974641,
#               31.866582
#             ],
#             [
#               35.225892,
#               31.754341
#             ],
#             [
#               34.970507,
#               31.616778
#             ],
#             [
#               34.927408,
#               31.353435
#             ],
#             [
#               35.397561,
#               31.489086
#             ],
#             [
#               35.420918,
#               31.100066
#             ],
#             [
#               34.922603,
#               29.501326
#             ],
#             [
#               34.823243,
#               29.761081
#             ],
#             [
#               34.26544,
#               31.21936
#             ],
#             [
#               34.265435,
#               31.219357
#             ],
#             [
#               34.265433,
#               31.219361
#             ],
#             [
#               34.556372,
#               31.548824
#             ],
#             [
#               34.488107,
#               31.605539
#             ],
#             [
#               34.752587,
#               32.072926
#             ],
#             [
#               34.955417,
#               32.827376
#             ],
#             [
#               35.098457,
#               33.080539
#             ],
#             [
#               35.126053,
#               33.0909
#             ],
#             [
#               35.460709,
#               33.08904
#             ],
#             [
#               35.552797,
#               33.264275
#             ],
#             [
#               35.821101,
#               33.277426
#             ],
#             [
#               35.836397,
#               32.868123
#             ],
#             [
#               35.700798,
#               32.716014
#             ],
#             [
#               35.719918,
#               32.709192
#             ]
#           ]
#         ]
#       },
#       "properties": {
#         "name": "Israel",
#         "value": 4140048.5897242688
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               35.821101,
#               33.277426
#             ],
#             [
#               35.552797,
#               33.264275
#             ],
#             [
#               35.460709,
#               33.08904
#             ],
#             [
#               35.126053,
#               33.0909
#             ],
#             [
#               35.482207,
#               33.90545
#             ],
#             [
#               35.979592,
#               34.610058
#             ],
#             [
#               35.998403,
#               34.644914
#             ],
#             [
#               36.448194,
#               34.593935
#             ],
#             [
#               36.61175,
#               34.201789
#             ],
#             [
#               36.06646,
#               33.824912
#             ],
#             [
#               35.821101,
#               33.277426
#             ]
#           ]
#         ]
#       },
#       "properties": {
#         "name": "Lebanon",
#         "value": 6968537.550483227
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               35.397561,
#               31.489086
#             ],
#             [
#               34.927408,
#               31.353435
#             ],
#             [
#               34.970507,
#               31.616778
#             ],
#             [
#               35.225892,
#               31.754341
#             ],
#             [
#               34.974641,
#               31.866582
#             ],
#             [
#               35.18393,
#               32.532511
#             ],
#             [
#               35.545665,
#               32.393992
#             ],
#             [
#               35.545252,
#               31.782505
#             ],
#             [
#               35.397561,
#               31.489086
#             ]
#           ]
#         ]
#       },
#       "properties": {
#         "name": "Palestine",
#         "value": 9754682.799512533
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               104.334335,
#               10.486544
#             ],
#             [
#               105.199915,
#               10.88931
#             ],
#             [
#               106.24967,
#               10.961812
#             ],
#             [
#               105.810524,
#               11.567615
#             ],
#             [
#               107.491403,
#               12.337206
#             ],
#             [
#               107.614548,
#               13.535531
#             ],
#             [
#               107.382727,
#               14.202441
#             ],
#             [
#               107.564525,
#               15.202173
#             ],
#             [
#               107.312706,
#               15.908538
#             ],
#             [
#               106.556008,
#               16.604284
#             ],
#             [
#               105.925762,
#               17.485315
#             ],
#             [
#               105.094598,
#               18.666975
#             ],
#             [
#               103.896532,
#               19.265181
#             ],
#             [
#               104.183388,
#               19.624668
#             ],
#             [
#               104.822574,
#               19.886642
#             ],
#             [
#               104.435,
#               20.758733
#             ],
#             [
#               103.203861,
#               20.766562
#             ],
#             [
#               102.754896,
#               21.675137
#             ],
#             [
#               102.170436,
#               22.464753
#             ],
#             [
#               102.706992,
#               22.708795
#             ],
#             [
#               103.504515,
#               22.703757
#             ],
#             [
#               104.476858,
#               22.81915
#             ],
#             [
#               105.329209,
#               23.352063
#             ],
#             [
#               105.811247,
#               22.976892
#             ],
#             [
#               106.725403,
#               22.794268
#             ],
#             [
#               106.567273,
#               22.218205
#             ],
#             [
#               107.04342,
#               21.811899
#             ],
#             [
#               108.05018,
#               21.55238
#             ],
#             [
#               106.715068,
#               20.696851
#             ],
#             [
#               105.881682,
#               19.75205
#             ],
#             [
#               105.662006,
#               19.058165
#             ],
#             [
#               106.426817,
#               18.004121
#             ],
#             [
#               107.361954,
#               16.697457
#             ],
#             [
#               108.269495,
#               16.079742
#             ],
#             [
#               108.877107,
#               15.276691
#             ],
#             [
#               109.33527,
#               13.426028
#             ],
#             [
#               109.200136,
#               11.666859
#             ],
#             [
#               108.36613,
#               11.008321
#             ],
#             [
#               107.220929,
#               10.364484
#             ],
#             [
#               106.405113,
#               9.53084
#             ],
#             [
#               105.158264,
#               8.59976
#             ],
#             [
#               104.795185,
#               9.241038
#             ],
#             [
#               105.076202,
#               9.918491
#             ],
#             [
#               104.334335,
#               10.486544
#             ]
#           ]
#         ]
#       },
#       "properties": {
#         "name": "Vietnam",
#         "value": 3378396.377624047
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               126.174759,
#               37.749686
#             ],
#             [
#               126.237339,
#               37.840378
#             ],
#             [
#               126.68372,
#               37.804773
#             ],
#             [
#               127.073309,
#               38.256115
#             ],
#             [
#               127.780035,
#               38.304536
#             ],
#             [
#               128.205746,
#               38.370397
#             ],
#             [
#               128.349716,
#               38.612243
#             ],
#             [
#               129.21292,
#               37.432392
#             ],
#             [
#               129.46045,
#               36.784189
#             ],
#             [
#               129.468304,
#               35.632141
#             ],
#             [
#               129.091377,
#               35.082484
#             ],
#             [
#               128.18585,
#               34.890377
#             ],
#             [
#               127.386519,
#               34.475674
#             ],
#             [
#               126.485748,
#               34.390046
#             ],
#             [
#               126.37392,
#               34.93456
#             ],
#             [
#               126.559231,
#               35.684541
#             ],
#             [
#               126.117398,
#               36.725485
#             ],
#             [
#               126.860143,
#               36.893924
#             ],
#             [
#               126.174759,
#               37.749686
#             ]
#           ]
#         ]
#       },
#       "properties": {
#         "name": "South Korea",
#         "value": 5194378.260938433
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               97.327114,
#               28.261583
#             ],
#             [
#               97.402561,
#               27.882536
#             ],
#             [
#               97.051989,
#               27.699059
#             ],
#             [
#               97.133999,
#               27.083774
#             ],
#             [
#               96.419366,
#               27.264589
#             ],
#             [
#               95.124768,
#               26.573572
#             ],
#             [
#               95.155153,
#               26.001307
#             ],
#             [
#               94.603249,
#               25.162495
#             ],
#             [
#               94.552658,
#               24.675238
#             ],
#             [
#               94.106742,
#               23.850741
#             ],
#             [
#               93.325188,
#               24.078556
#             ],
#             [
#               93.286327,
#               23.043658
#             ],
#             [
#               93.060294,
#               22.703111
#             ],
#             [
#               93.166128,
#               22.27846
#             ],
#             [
#               92.672721,
#               22.041239
#             ],
#             [
#               92.146035,
#               23.627499
#             ],
#             [
#               91.869928,
#               23.624346
#             ],
#             [
#               91.706475,
#               22.985264
#             ],
#             [
#               91.158963,
#               23.503527
#             ],
#             [
#               91.46773,
#               24.072639
#             ],
#             [
#               91.915093,
#               24.130414
#             ],
#             [
#               92.376202,
#               24.976693
#             ],
#             [
#               91.799596,
#               25.147432
#             ],
#             [
#               90.872211,
#               25.132601
#             ],
#             [
#               89.920693,
#               25.26975
#             ],
#             [
#               89.832481,
#               25.965082
#             ],
#             [
#               89.355094,
#               26.014407
#             ],
#             [
#               88.563049,
#               26.446526
#             ],
#             [
#               88.209789,
#               25.768066
#             ],
#             [
#               88.931554,
#               25.238692
#             ],
#             [
#               88.306373,
#               24.866079
#             ],
#             [
#               88.084422,
#               24.501657
#             ],
#             [
#               88.69994,
#               24.233715
#             ],
#             [
#               88.52977,
#               23.631142
#             ],
#             [
#               88.876312,
#               22.879146
#             ],
#             [
#               89.031961,
#               22.055708
#             ],
#             [
#               88.888766,
#               21.690588
#             ],
#             [
#               88.208497,
#               21.703172
#             ],
#             [
#               86.975704,
#               21.495562
#             ],
#             [
#               87.033169,
#               20.743308
#             ],
#             [
#               86.499351,
#               20.151638
#             ],
#             [
#               85.060266,
#               19.478579
#             ],
#             [
#               83.941006,
#               18.30201
#             ],
#             [
#               83.189217,
#               17.671221
#             ],
#             [
#               82.192792,
#               17.016636
#             ],
#             [
#               82.191242,
#               16.556664
#             ],
#             [
#               81.692719,
#               16.310219
#             ],
#             [
#               80.791999,
#               15.951972
#             ],
#             [
#               80.324896,
#               15.899185
#             ],
#             [
#               80.025069,
#               15.136415
#             ],
#             [
#               80.233274,
#               13.835771
#             ],
#             [
#               80.286294,
#               13.006261
#             ],
#             [
#               79.862547,
#               12.056215
#             ],
#             [
#               79.857999,
#               10.357275
#             ],
#             [
#               79.340512,
#               10.308854
#             ],
#             [
#               78.885345,
#               9.546136
#             ],
#             [
#               79.18972,
#               9.216544
#             ],
#             [
#               78.277941,
#               8.933047
#             ],
#             [
#               77.941165,
#               8.252959
#             ],
#             [
#               77.539898,
#               7.965535
#             ],
#             [
#               76.592979,
#               8.899276
#             ],
#             [
#               76.130061,
#               10.29963
#             ],
#             [
#               75.746467,
#               11.308251
#             ],
#             [
#               75.396101,
#               11.781245
#             ],
#             [
#               74.864816,
#               12.741936
#             ],
#             [
#               74.616717,
#               13.992583
#             ],
#             [
#               74.443859,
#               14.617222
#             ],
#             [
#               73.534199,
#               15.990652
#             ],
#             [
#               73.119909,
#               17.92857
#             ],
#             [
#               72.820909,
#               19.208234
#             ],
#             [
#               72.824475,
#               20.419503
#             ],
#             [
#               72.630533,
#               21.356009
#             ],
#             [
#               71.175273,
#               20.757441
#             ],
#             [
#               70.470459,
#               20.877331
#             ],
#             [
#               69.16413,
#               22.089298
#             ],
#             [
#               69.644928,
#               22.450775
#             ],
#             [
#               69.349597,
#               22.84318
#             ],
#             [
#               68.176645,
#               23.691965
#             ],
#             [
#               68.842599,
#               24.359134
#             ],
#             [
#               71.04324,
#               24.356524
#             ],
#             [
#               70.844699,
#               25.215102
#             ],
#             [
#               70.282873,
#               25.722229
#             ],
#             [
#               70.168927,
#               26.491872
#             ],
#             [
#               69.514393,
#               26.940966
#             ],
#             [
#               70.616496,
#               27.989196
#             ],
#             [
#               71.777666,
#               27.91318
#             ],
#             [
#               72.823752,
#               28.961592
#             ],
#             [
#               73.450638,
#               29.976413
#             ],
#             [
#               74.42138,
#               30.979815
#             ],
#             [
#               74.405929,
#               31.692639
#             ],
#             [
#               75.258642,
#               32.271105
#             ],
#             [
#               74.451559,
#               32.7649
#             ],
#             [
#               74.104294,
#               33.441473
#             ],
#             [
#               73.749948,
#               34.317699
#             ],
#             [
#               74.240203,
#               34.748887
#             ],
#             [
#               75.757061,
#               34.504923
#             ],
#             [
#               76.871722,
#               34.653544
#             ],
#             [
#               77.837451,
#               35.49401
#             ],
#             [
#               78.912269,
#               34.321936
#             ],
#             [
#               78.811086,
#               33.506198
#             ],
#             [
#               79.208892,
#               32.994395
#             ],
#             [
#               79.176129,
#               32.48378
#             ],
#             [
#               78.458446,
#               32.618164
#             ],
#             [
#               78.738894,
#               31.515906
#             ],
#             [
#               79.721367,
#               30.882715
#             ],
#             [
#               81.111256,
#               30.183481
#             ],
#             [
#               80.476721,
#               29.729865
#             ],
#             [
#               80.088425,
#               28.79447
#             ],
#             [
#               81.057203,
#               28.416095
#             ],
#             [
#               81.999987,
#               27.925479
#             ],
#             [
#               83.304249,
#               27.364506
#             ],
#             [
#               84.675018,
#               27.234901
#             ],
#             [
#               85.251779,
#               26.726198
#             ],
#             [
#               86.024393,
#               26.630985
#             ],
#             [
#               87.227472,
#               26.397898
#             ],
#             [
#               88.060238,
#               26.414615
#             ],
#             [
#               88.174804,
#               26.810405
#             ],
#             [
#               88.043133,
#               27.445819
#             ],
#             [
#               88.120441,
#               27.876542
#             ],
#             [
#               88.730326,
#               28.086865
#             ],
#             [
#               88.814248,
#               27.299316
#             ],
#             [
#               88.835643,
#               27.098966
#             ],
#             [
#               89.744528,
#               26.719403
#             ],
#             [
#               90.373275,
#               26.875724
#             ],
#             [
#               91.217513,
#               26.808648
#             ],
#             [
#               92.033484,
#               26.83831
#             ],
#             [
#               92.103712,
#               27.452614
#             ],
#             [
#               91.696657,
#               27.771742
#             ],
#             [
#               92.503119,
#               27.896876
#             ],
#             [
#               93.413348,
#               28.640629
#             ],
#             [
#               94.56599,
#               29.277438
#             ],
#             [
#               95.404802,
#               29.031717
#             ],
#             [
#               96.117679,
#               29.452802
#             ],
#             [
#               96.586591,
#               28.83098
#             ],
#             [
#               96.248833,
#               28.411031
#             ],
#             [
#               97.327114,
#               28.261583
#             ]
#           ]
#         ]
#       },
#       "properties": {
#         "name": "India",
#         "value": 4916503.213323983
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               92.672721,
#               22.041239
#             ],
#             [
#               92.652257,
#               21.324048
#             ],
#             [
#               92.303234,
#               21.475485
#             ],
#             [
#               92.368554,
#               20.670883
#             ],
#             [
#               92.082886,
#               21.192195
#             ],
#             [
#               92.025215,
#               21.70157
#             ],
#             [
#               91.834891,
#               22.182936
#             ],
#             [
#               91.417087,
#               22.765019
#             ],
#             [
#               90.496006,
#               22.805017
#             ],
#             [
#               90.586957,
#               22.392794
#             ],
#             [
#               90.272971,
#               21.836368
#             ],
#             [
#               89.847467,
#               22.039146
#             ],
#             [
#               89.70205,
#               21.857116
#             ],
#             [
#               89.418863,
#               21.966179
#             ],
#             [
#               89.031961,
#               22.055708
#             ],
#             [
#               88.876312,
#               22.879146
#             ],
#             [
#               88.52977,
#               23.631142
#             ],
#             [
#               88.69994,
#               24.233715
#             ],
#             [
#               88.084422,
#               24.501657
#             ],
#             [
#               88.306373,
#               24.866079
#             ],
#             [
#               88.931554,
#               25.238692
#             ],
#             [
#               88.209789,
#               25.768066
#             ],
#             [
#               88.563049,
#               26.446526
#             ],
#             [
#               89.355094,
#               26.014407
#             ],
#             [
#               89.832481,
#               25.965082
#             ],
#             [
#               89.920693,
#               25.26975
#             ],
#             [
#               90.872211,
#               25.132601
#             ],
#             [
#               91.799596,
#               25.147432
#             ],
#             [
#               92.376202,
#               24.976693
#             ],
#             [
#               91.915093,
#               24.130414
#             ],
#             [
#               91.46773,
#               24.072639
#             ],
#             [
#               91.158963,
#               23.503527
#             ],
#             [
#               91.706475,
#               22.985264
#             ],
#             [
#               91.869928,
#               23.624346
#             ],
#             [
#               92.146035,
#               23.627499
#             ],
#             [
#               92.672721,
#               22.041239
#             ]
#           ]
#         ]
#       },
#       "properties": {
#         "name": "Bangladesh",
#         "value": 13750842.585969182
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               6.90514,
#               53.482162
#             ],
#             [
#               7.092053,
#               53.144043
#             ],
#             [
#               6.84287,
#               52.22844
#             ],
#             [
#               6.589397,
#               51.852029
#             ],
#             [
#               5.988658,
#               51.851616
#             ],
#             [
#               6.156658,
#               50.803721
#             ],
#             [
#               5.606976,
#               51.037298
#             ],
#             [
#               4.973991,
#               51.475024
#             ],
#             [
#               4.047071,
#               51.267259
#             ],
#             [
#               3.314971,
#               51.345755
#             ],
#             [
#               3.315011,
#               51.345777
#             ],
#             [
#               3.830289,
#               51.620545
#             ],
#             [
#               4.705997,
#               53.091798
#             ],
#             [
#               6.074183,
#               53.510403
#             ],
#             [
#               6.90514,
#               53.482162
#             ]
#           ]
#         ]
#       },
#       "properties": {
#         "name": "Netherlands",
#         "value": 3292602.3652927773
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               81.787959,
#               7.523055
#             ],
#             [
#               81.637322,
#               6.481775
#             ],
#             [
#               81.21802,
#               6.197141
#             ],
#             [
#               80.348357,
#               5.96837
#             ],
#             [
#               79.872469,
#               6.763463
#             ],
#             [
#               79.695167,
#               8.200843
#             ],
#             [
#               80.147801,
#               9.824078
#             ],
#             [
#               80.838818,
#               9.268427
#             ],
#             [
#               81.304319,
#               8.564206
#             ],
#             [
#               81.787959,
#               7.523055
#             ]
#           ]
#         ]
#       },
#       "properties": {
#         "name": "Sri Lanka",
#         "value": 4069422.297867995
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               121.777818,
#               24.394274
#             ],
#             [
#               121.175632,
#               22.790857
#             ],
#             [
#               120.74708,
#               21.970571
#             ],
#             [
#               120.220083,
#               22.814861
#             ],
#             [
#               120.106189,
#               23.556263
#             ],
#             [
#               120.69468,
#               24.538451
#             ],
#             [
#               121.495044,
#               25.295459
#             ],
#             [
#               121.951244,
#               24.997596
#             ],
#             [
#               121.777818,
#               24.394274
#             ]
#           ]
#         ]
#       },
#       "properties": {
#         "name": "Taiwan",
#         "value": 7744571.601705644
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "MultiPolygon",
#         "coordinates": [
#           [
#             [
#               [
#                 120.833896,
#                 12.704496
#               ],
#               [
#                 120.323436,
#                 13.466413
#               ],
#               [
#                 121.180128,
#                 13.429697
#               ],
#               [
#                 121.527394,
#                 13.06959
#               ],
#               [
#                 121.26219,
#                 12.20556
#               ],
#               [
#                 120.833896,
#                 12.704496
#               ]
#             ]
#           ],
#           [
#             [
#               [
#                 122.586089,
#                 9.981045
#               ],
#               [
#                 122.837081,
#                 10.261157
#               ],
#               [
#                 122.947411,
#                 10.881868
#               ],
#               [
#                 123.49885,
#                 10.940624
#               ],
#               [
#                 123.337774,
#                 10.267384
#               ],
#               [
#                 124.077936,
#                 11.232726
#               ],
#               [
#                 123.982438,
#                 10.278779
#               ],
#               [
#                 123.623183,
#                 9.950091
#               ],
#               [
#                 123.309921,
#                 9.318269
#               ],
#               [
#                 122.995883,
#                 9.022189
#               ],
#               [
#                 122.380055,
#                 9.713361
#               ],
#               [
#                 122.586089,
#                 9.981045
#               ]
#             ]
#           ],
#           [
#             [
#               [
#                 126.376814,
#                 8.414706
#               ],
#               [
#                 126.478513,
#                 7.750354
#               ],
#               [
#                 126.537424,
#                 7.189381
#               ],
#               [
#                 126.196773,
#                 6.274294
#               ],
#               [
#                 125.831421,
#                 7.293715
#               ],
#               [
#                 125.363852,
#                 6.786485
#               ],
#               [
#                 125.683161,
#                 6.049657
#               ],
#               [
#                 125.396512,
#                 5.581003
#               ],
#               [
#                 124.219788,
#                 6.161355
#               ],
#               [
#                 123.93872,
#                 6.885136
#               ],
#               [
#                 124.243662,
#                 7.36061
#               ],
#               [
#                 123.610212,
#                 7.833527
#               ],
#               [
#                 123.296071,
#                 7.418876
#               ],
#               [
#                 122.825506,
#                 7.457375
#               ],
#               [
#                 122.085499,
#                 6.899424
#               ],
#               [
#                 121.919928,
#                 7.192119
#               ],
#               [
#                 122.312359,
#                 8.034962
#               ],
#               [
#                 122.942398,
#                 8.316237
#               ],
#               [
#                 123.487688,
#                 8.69301
#               ],
#               [
#                 123.841154,
#                 8.240324
#               ],
#               [
#                 124.60147,
#                 8.514158
#               ],
#               [
#                 124.764612,
#                 8.960409
#               ],
#               [
#                 125.471391,
#                 8.986997
#               ],
#               [
#                 125.412118,
#                 9.760335
#               ],
#               [
#                 126.222714,
#                 9.286074
#               ],
#               [
#                 126.306637,
#                 8.782487
#               ],
#               [
#                 126.376814,
#                 8.414706
#               ]
#             ]
#           ],
#           [
#             [
#               [
#                 118.504581,
#                 9.316383
#               ],
#               [
#                 117.174275,
#                 8.3675
#               ],
#               [
#                 117.664477,
#                 9.066889
#               ],
#               [
#                 118.386914,
#                 9.6845
#               ],
#               [
#                 118.987342,
#                 10.376292
#               ],
#               [
#                 119.511496,
#                 11.369668
#               ],
#               [
#                 119.689677,
#                 10.554291
#               ],
#               [
#                 119.029458,
#                 10.003653
#               ],
#               [
#                 118.504581,
#                 9.316383
#               ]
#             ]
#           ],
#           [
#             [
#               [
#                 122.336957,
#                 18.224883
#               ],
#               [
#                 122.174279,
#                 17.810283
#               ],
#               [
#                 122.515654,
#                 17.093505
#               ],
#               [
#                 122.252311,
#                 16.262444
#               ],
#               [
#                 121.662786,
#                 15.931018
#               ],
#               [
#                 121.50507,
#                 15.124814
#               ],
#               [
#                 121.728829,
#                 14.328376
#               ],
#               [
#                 122.258925,
#                 14.218202
#               ],
#               [
#                 122.701276,
#                 14.336541
#               ],
#               [
#                 123.950295,
#                 13.782131
#               ],
#               [
#                 123.855107,
#                 13.237771
#               ],
#               [
#                 124.181289,
#                 12.997527
#               ],
#               [
#                 124.077419,
#                 12.536677
#               ],
#               [
#                 123.298035,
#                 13.027526
#               ],
#               [
#                 122.928652,
#                 13.55292
#               ],
#               [
#                 122.671355,
#                 13.185836
#               ],
#               [
#                 122.03465,
#                 13.784482
#               ],
#               [
#                 121.126385,
#                 13.636687
#               ],
#               [
#                 120.628637,
#                 13.857656
#               ],
#               [
#                 120.679384,
#                 14.271016
#               ],
#               [
#                 120.991819,
#                 14.525393
#               ],
#               [
#                 120.693336,
#                 14.756671
#               ],
#               [
#                 120.564145,
#                 14.396279
#               ],
#               [
#                 120.070429,
#                 14.970869
#               ],
#               [
#                 119.920929,
#                 15.406347
#               ],
#               [
#                 119.883773,
#                 16.363704
#               ],
#               [
#                 120.286488,
#                 16.034629
#               ],
#               [
#                 120.390047,
#                 17.599081
#               ],
#               [
#                 120.715867,
#                 18.505227
#               ],
#               [
#                 121.321308,
#                 18.504065
#               ],
#               [
#                 121.937601,
#                 18.218552
#               ],
#               [
#                 122.246006,
#                 18.47895
#               ],
#               [
#                 122.336957,
#                 18.224883
#               ]
#             ]
#           ],
#           [
#             [
#               [
#                 122.03837,
#                 11.415841
#               ],
#               [
#                 121.883548,
#                 11.891755
#               ],
#               [
#                 122.483821,
#                 11.582187
#               ],
#               [
#                 123.120217,
#                 11.58366
#               ],
#               [
#                 123.100838,
#                 11.165934
#               ],
#               [
#                 122.637714,
#                 10.741308
#               ],
#               [
#                 122.00261,
#                 10.441017
#               ],
#               [
#                 121.967367,
#                 10.905691
#               ],
#               [
#                 122.03837,
#                 11.415841
#               ]
#             ]
#           ],
#           [
#             [
#               [
#                 125.502552,
#                 12.162695
#               ],
#               [
#                 125.783465,
#                 11.046122
#               ],
#               [
#                 125.011884,
#                 11.311455
#               ],
#               [
#                 125.032761,
#                 10.975816
#               ],
#               [
#                 125.277449,
#                 10.358722
#               ],
#               [
#                 124.801819,
#                 10.134679
#               ],
#               [
#                 124.760168,
#                 10.837995
#               ],
#               [
#                 124.459101,
#                 10.88993
#               ],
#               [
#                 124.302522,
#                 11.495371
#               ],
#               [
#                 124.891013,
#                 11.415583
#               ],
#               [
#                 124.87799,
#                 11.79419
#               ],
#               [
#                 124.266762,
#                 12.557761
#               ],
#               [
#                 125.227116,
#                 12.535721
#               ],
#               [
#                 125.502552,
#                 12.162695
#               ]
#             ]
#           ]
#         ]
#       },
#       "properties": {
#         "name": "Philippines",
#         "value": 4451215.885604435
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               30.419105,
#               -1.134659
#             ],
#             [
#               30.816135,
#               -1.698914
#             ],
#             [
#               30.758309,
#               -2.28725
#             ],
#             [
#               30.46967,
#               -2.41383
#             ],
#             [
#               30.469674,
#               -2.413855
#             ],
#             [
#               29.938359,
#               -2.348487
#             ],
#             [
#               29.632176,
#               -2.917858
#             ],
#             [
#               29.024926,
#               -2.839258
#             ],
#             [
#               29.117479,
#               -2.292211
#             ],
#             [
#               29.254835,
#               -2.21511
#             ],
#             [
#               29.291887,
#               -1.620056
#             ],
#             [
#               29.579466,
#               -1.341313
#             ],
#             [
#               29.821519,
#               -1.443322
#             ],
#             [
#               30.419105,
#               -1.134659
#             ]
#           ]
#         ]
#       },
#       "properties": {
#         "name": "Rwanda",
#         "value": 6647861.182503427
#       }
#     }
#   ]
# }

# %% [markdown]
# ### GeoJSON を地図上に表示する

# %%
import folium
import json

geojson_data = json.loads(geojson_output)

m = folium.Map(location=[0, 0], zoom_start=2)  # default map

# Add the GeoJSON data to the map
folium.GeoJson(geojson_data).add_to(m)

# Get bounds from GeoJSON data and fit the map to those bounds
# Extract bounds from geojson_data
bounds = folium.GeoJson(geojson_data).get_bounds()
# Ensure bounds are valid before fitting
if bounds:
    m.fit_bounds(bounds)

# Display the map
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a674825ed2b1ca53ab0882032b0bdf17 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a674825ed2b1ca53ab0882032b0bdf17&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a674825ed2b1ca53ab0882032b0bdf17 = L.map(
#                 &quot;map_a674825ed2b1ca53ab0882032b0bdf17&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_15e82693204dc95014eb4c9b5a300eb7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_15e82693204dc95014eb4c9b5a300eb7.addTo(map_a674825ed2b1ca53ab0882032b0bdf17);
#
#
#
#         function geo_json_9d14d0621528727e82f4684dd5d571a4_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_9d14d0621528727e82f4684dd5d571a4 = L.geoJson(null, {
#                 onEachFeature: geo_json_9d14d0621528727e82f4684dd5d571a4_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_9d14d0621528727e82f4684dd5d571a4_add (data) {
#             geo_json_9d14d0621528727e82f4684dd5d571a4
#                 .addData(data);
#         }
#             geo_json_9d14d0621528727e82f4684dd5d571a4_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-71.712361, 19.714456], [-71.624873, 19.169838], [-71.701303, 18.785417], [-71.945112, 18.6169], [-71.687738, 18.31666], [-71.708305, 18.044997], [-72.372476, 18.214961], [-72.844411, 18.145611], [-73.454555, 18.217906], [-73.922433, 18.030993], [-74.458034, 18.34255], [-74.369925, 18.664908], [-73.449542, 18.526053], [-72.694937, 18.445799], [-72.334882, 18.668422], [-72.79165, 19.101625], [-72.784105, 19.483591], [-73.415022, 19.639551], [-73.189791, 19.915684], [-72.579673, 19.871501], [-71.712361, 19.714456]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;Haiti&quot;, &quot;value&quot;: 4602594.646601417}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-89.353326, 14.424133], [-89.058512, 14.340029], [-88.843073, 14.140507], [-88.541231, 13.980155], [-88.503998, 13.845486], [-88.065343, 13.964626], [-87.859515, 13.893312], [-87.723503, 13.78505], [-87.793111, 13.38448], [-87.904112, 13.149017], [-88.483302, 13.163951], [-88.843228, 13.259734], [-89.256743, 13.458533], [-89.812394, 13.520622], [-90.095555, 13.735338], [-90.064678, 13.88197], [-89.721934, 14.134228], [-89.534219, 14.244816], [-89.587343, 14.362586], [-89.353326, 14.424133]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;El Salvador&quot;, &quot;value&quot;: 3696006.632444857}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-66.282434, 18.514762], [-65.771303, 18.426679], [-65.591004, 18.228035], [-65.847164, 17.975906], [-66.599934, 17.981823], [-67.184162, 17.946553], [-67.242428, 18.37446], [-67.100679, 18.520601], [-66.282434, 18.514762]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;Puerto Rico&quot;, &quot;value&quot;: 4052864.9406663175}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[30.469674, -2.413855], [30.52766, -2.80762], [30.74301, -3.03431], [30.75224, -3.35931], [30.50554, -3.56858], [30.11632, -4.09012], [29.753512, -4.452389], [29.339998, -4.499983], [29.276384, -3.293907], [29.024926, -2.839258], [29.632176, -2.917858], [29.938359, -2.348487], [30.469674, -2.413855]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;Burundi&quot;, &quot;value&quot;: 5399902.326990314}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[35.719918, 32.709192], [35.545665, 32.393992], [35.18393, 32.532511], [34.974641, 31.866582], [35.225892, 31.754341], [34.970507, 31.616778], [34.927408, 31.353435], [35.397561, 31.489086], [35.420918, 31.100066], [34.922603, 29.501326], [34.823243, 29.761081], [34.26544, 31.21936], [34.265435, 31.219357], [34.265433, 31.219361], [34.556372, 31.548824], [34.488107, 31.605539], [34.752587, 32.072926], [34.955417, 32.827376], [35.098457, 33.080539], [35.126053, 33.0909], [35.460709, 33.08904], [35.552797, 33.264275], [35.821101, 33.277426], [35.836397, 32.868123], [35.700798, 32.716014], [35.719918, 32.709192]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;Israel&quot;, &quot;value&quot;: 4140048.5897242688}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[35.821101, 33.277426], [35.552797, 33.264275], [35.460709, 33.08904], [35.126053, 33.0909], [35.482207, 33.90545], [35.979592,

# %% [markdown]
# ## OpenStreetMap Overpass API
#
# ### Overpass API の概要
#
# - Overpass API は、OpenStreetMap のデータを取得するための読み取り専用の API です
#   - https://overpass-turbo.eu/
#   - https://wiki.openstreetmap.org/wiki/JA:Overpass_API
# - Overpass API は、 XML または Overpass QL という専用のクエリ言語を使用してデータを取得します
#   - https://wiki.openstreetmap.org/wiki/JA:Overpass_API/Overpass_QL
#
# ### 注意
#
# - このノートブックでは、 z.overpass-api.de で提供されている Overpass API を使用しています
# - z.overpass-api.de で提供されている Overpass API は、 **一日あたり10,000クエリまたは1GBのデータ取得** が目安です
#   - この頻度を超えるリクエストが必要な場合は、自分で Overpass API サーバーを立てることができます
#   - インストール方法は公式ドキュメントを参照してください
#     - https://overpass-api.de/no_frills.html
#     - https://overpass-api.de/full_installation.html
#     - https://wiki.openstreetmap.org/wiki/Overpass_API/Installation

# %% [markdown]
# ### このノートブックの流れ
#
# - 生成 AI に、自然言語から Overpass QL を出力させる
# - 出力された Overpass QL で、 Overpass API からデータを取得する
# - 取得したデータを GeoJSON に変換する
# - GeoJSON を地図上に表示する

# %% [markdown]
# ### 前準備

# %% [markdown]
# ### 対象となる自然言語

# %%
input_text = "長崎県長崎市のカフェを地図に表示してください。"
print(input_text)
# Out:
# 長崎県長崎市のカフェを地図に表示してください。

# %% [markdown]
# ### 生成 AI に自然言語から Overpass QL を出力させる

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI

# モデルの準備
model = ChatGoogleGenerativeAI(model="gemini-exp-1206", temperature=0)

# プロンプトの準備
template = """You are an expert in Overpass API Query.
Output the appropriate Overpass API Query from the user input.

You will always reply according to the following rules:
- Output valid Overpass API query.
- The query MUST be out json.
- The query MUST be out geom.
- The query MUST be set timeout as 30000.
- The query will utilize a area specifier as needed.
- The query will search nwr as needed.
- The query MUST be line delimited and surrounded by just three backquote to indicate that it is a code block.

Hints:
- Regardless of the language of the user input, use area["name"="..."]. Because the area names are in the local language.
- If the user input is for a specific type of restaurant, amenity should be restaurant and filter by cuisine.

** Important **
Take a deep breath and carefully check if it is in accordance with the rules and appropriate as an Overpass API Query.

User Input:
{input}
"""
prompt = ChatPromptTemplate.from_template(template)

chain = prompt | model

res = chain.invoke({"input": input_text})
result = res.content.strip()
print(result)
# Out:
# ```
# [out:json][timeout:30000];
# area["name"="長崎市"]->.searchArea;
# (
#   nwr["amenity"="cafe"](area.searchArea);
# );
# out geom;
# ```

# %%
# resultから ``` を使って Overpass QL のみを抽出

import re

# 正規表現でコードブロックの中身を抽出
match = re.search(r"```[^\n]*\n(.*?)```", result, re.DOTALL)

if match:
    overpass_query = match.group(1).strip()
    print(overpass_query)
else:
    print("Overpass API Queryが見つかりませんでした。")
# Out:
# [out:json][timeout:30000];
# area["name"="長崎市"]->.searchArea;
# (
#   nwr["amenity"="cafe"](area.searchArea);
# );
# out geom;

# %% [markdown]
# ### 出力された Overpass QL で Overpass API からデータを取得する

# %%
import requests

def get_overpass_response(overpass_query: str):
    query_string = f"data={requests.utils.quote(overpass_query)}"
    overpass_api_url = f"https://z.overpass-api.de/api/interpreter?{query_string}"
    response = requests.get(overpass_api_url)
    if response.status_code == 200:
        res_json = response.json()
        return res_json
    else:
        print(f"Error: {response.status_code}")
        print(response.text)
        return None

# %%
import json

overpass_response = get_overpass_response(overpass_query)
print(json.dumps(overpass_response, indent=2, ensure_ascii=False))
print(len(overpass_response['elements']))
# Out:
# {
#   "version": 0.6,
#   "generator": "Overpass API 0.7.62.5 1bd436f1",
#   "osm3s": {
#     "timestamp_osm_base": "2025-03-08T10:15:36Z",
#     "timestamp_areas_base": "2024-12-31T00:49:33Z",
#     "copyright": "The data included in this document is from www.openstreetmap.org. The data is made available under ODbL."
#   },
#   "elements": [
#     {
#       "type": "node",
#       "id": 2503809124,
#       "lat": 32.7360454,
#       "lon": 129.8703754,
#       "tags": {
#         "amenity": "cafe",
#         "layer": "1",
#         "level": "1",
#         "name": "タイム",
#         "source": "image,2013-09;Bing,2011-07-11"
#       }
#     },
#     {
#       "type": "node",
#       "id": 2503853734,
#       "lat": 32.7359147,
#       "lon": 129.8695208,
#       "tags": {
#         "amenity": "cafe",
#         "name": "BRICK CAFE",
#         "source": "image,2013-09;Bing,2011-07-11"
#       }
#     },
#     {
#       "type": "node",
#       "id": 2503894610,
#       "lat": 32.7357577,
#       "lon": 129.8698889,
#       "tags": {
#         "amenity": "cafe",
#         "name": "トレビ",
#         "name:en": "TOREVI",
#         "source": "image,2013-09;Bing,2011-07-11"
#       }
#     },
#     {
#       "type": "node",
#       "id": 2503923835,
#       "lat": 32.7350887,
#       "lon": 129.8700096,
#       "tags": {
#         "amenity": "cafe",
#         "name": "CAFE 1571",
#         "source": "image,2013-09;Bing,2011-07-11"
#       }
#     },
#     {
#       "type": "node",
#       "id": 4682069782,
#       "lat": 32.7833873,
#       "lon": 129.8591467,
#       "tags": {
#         "amenity": "cafe"
#       }
#     },
#     {
#       "type": "node",
#       "id": 4813290124,
#       "lat": 32.7431669,
#       "lon": 129.8765886,
#       "tags": {
#         "amenity": "cafe",
#         "branch": "長崎西浜通り店",
#         "brand": "カフェ・ベローチェ",
#         "brand:en": "CAFFÈ VELOCE",
#         "brand:ja": "カフェ・ベローチェ",
#         "brand:wikidata": "Q11294597",
#         "brand:wikipedia": "ja:カフェ・ベローチェ",
#         "cuisine": "coffee_shop",
#         "internet_access": "wlan",
#         "internet_access:fee": "no",
#         "name": "カフェ・ベローチェ",
#         "name:en": "CAFFÈ VELOCE",
#         "name:ja": "カフェ・ベローチェ",
#         "opening_hours": "Mo-Su 07:15-23:00",
#         "outdoor_seating": "no",
#         "smoking": "isolated",
#         "takeaway": "yes",
#         "website": "https://chatnoir-company.com/chatnoir/ShopSearch?shop_code=378"
#       }
#     },
#     {
#       "type": "node",
#       "id": 5625966022,
#       "lat": 32.7458305,
#       "lon": 129.8712687,
#       "tags": {
#         "amenity": "cafe",
#         "name": "Blueprint"
#       }
#     },
#     {
#       "type": "node",
#       "id": 5632636921,
#       "lat": 32.7040395,
#       "lon": 129.9107791,
#       "tags": {
#         "amenity": "cafe",
#         "name": "笑くぼ",
#         "name:en": "Ekubo"
#       }
#     },
#     {
#       "type": "node",
#       "id": 5783704158,
#       "lat": 32.7758285,
#       "lon": 129.8657634,
#       "tags": {
#         "amenity": "cafe",
#         "name:en": "Juma Cafe"
#       }
#     },
#     {
#       "type": "node",
#       "id": 6380332250,
#       "lat": 32.7437759,
#       "lon": 129.8706219,
#       "tags": {
#         "amenity": "cafe",
#         "internet_access": "no",
#         "name": "Attic Coffee"
#       }
#     },
#     {
#       "type": "node",
#       "id": 6797843142,
#       "lat": 32.7428008,
#       "lon": 129.8741488,
#       "tags": {
#         "amenity": "cafe",
#         "internet_access": "wlan",
#         "internet_access:fee": "no",
#         "name": "Branch Otto",
#         "opening_hours": "10:30-22:00",
#         "outdoor_seating": "yes",
#         "wheelchair": "yes"
#       }
#     },
#     {
#       "type": "node",
#       "id": 6797844281,
#       "lat": 32.7520273,
#       "lon": 129.8711927,
#       "tags": {
#         "amenity": "cafe",
#         "brand": "スターバックス",
#         "brand:en": "Starbucks",
#         "brand:ja": "スターバックス",
#         "brand:wikidata": "Q37158",
#         "brand:wikipedia": "en:Starbucks",
#         "cuisine": "coffee_shop",
#         "name": "スターバックス",
#         "name:en": "Starbucks",
#         "name:ja": "スターバックス",
#         "official_name": "スターバックスコーヒー",
#         "official_name:en": "Starbucks Coffee",
#         "official_name:ja": "スターバックスコーヒー",
#         "opening_hours": "Mo-Su 07:30-22:00",
#         "outdoor_seating": "yes",
#         "takeaway": "yes"
#       }
#     },
#     {
#       "type": "node",
#       "id": 7100478858,
#       "lat": 32.7434292,
#       "lon": 129.8801211,
#       "tags": {
#         "amenity": "cafe",
#         "name": "CAFFE VELOCE"
#       }
#     },
#     {
#       "type": "node",
#       "id": 7304607285,
#       "lat": 32.7347773,
#       "lon": 129.8728574,
#       "tags": {
#         "amenity": "cafe",
#         "name:en": "Café Maman"
#       }
#     },
#     {
#       "type": "node",
#       "id": 7774585087,
#       "lat": 32.8050515,
#       "lon": 129.8358444,
#       "tags": {
#         "amenity": "cafe",
#         "name": "からしま自家焙煎珈琲舎"
#       }
#     },
#     {
#       "type": "node",
#       "id": 10752213505,
#       "lat": 32.7755426,
#       "lon": 129.8656126,
#       "tags": {
#         "amenity": "cafe",
#         "name:en": "Cafe Dining Mammy"
#       }
#     },
#     {
#       "type": "node",
#       "id": 10975657422,
#       "lat": 32.7417137,
#       "lon": 129.8707975,
#       "tags": {
#         "amenity": "cafe",
#         "name": "長崎県美術館カフェ",
#         "twitter": "npam_cafe",
#         "website": "http://www.nagasaki-museum.jp/goods2/?mainlabel=%E3%82%AB%E3%83%95%E3%82%A7"
#       }
#     },
#     {
#       "type": "node",
#       "id": 11558619052,
#       "lat": 32.7450868,
#       "lon": 129.8779672,
#       "tags": {
#         "addr:block_number": "2",
#         "addr:city": "長崎市",
#         "addr:housename": "街ビル 2",
#         "addr:neighbourhood": "浜町",
#         "addr:province": "長崎県",
#         "air_conditioning": "yes",
#         "amenity": "cafe",
#         "contact:email": "june6coffee@gmail.com",
#         "contact:instagram": "junecoffee_hama",
#         "diet:vegan": "limited",
#         "diet:vegan:description": "Only Soy milk",
#         "diet:vegetarian": "yes",
#         "indoor_seating": "yes",
#         "level": "0",
#         "level:ref": "1F",
#         "name": "June Coffee 浜の町店",
#         "opening_hours": "Mo-Su 10:30-18:30; closed \"年末年始\"",
#         "outdoor_seating": "no",
#         "payment:credit_cards": "yes",
#         "payment:debit_cards": "yes",
#         "smoking": "no",
#         "toilets": "yes",
#         "wheelchair": "yes"
#       }
#     },
#     {
#       "type": "node",
#       "id": 11566482666,
#       "lat": 32.7535974,
#       "lon": 129.8712324,
#       "tags": {
#         "addr:block_number": "2",
#         "addr:city": "長崎市",
#         "addr:housenumber": "5",
#         "addr:neighbourhood": "大黒町",
#         "addr:province": "長崎県",
#         "air_conditioning": "yes",
#         "amenity": "cafe",
#         "contact:instagram": "ngs_coffee",
#         "diet:vegan": "no",
#         "diet:vegetarian": "yes",
#         "indoor_seating": "yes",
#         "level": "0",
#         "level:ref": "1F",
#         "name": "NGS Coffee",
#         "opening_hours": "Mo-Su 08:00-20:00",
#         "operator:website": "https://neutral-holdings.co.jp",
#         "outdoor_seating": "no",
#         "payment:credit_cards": "yes",
#         "payment:debit_cards": "yes",
#         "phone": "+81 095-895-5727",
#         "smoking": "no",
#         "website": "https://fuk-coffee.com",
#         "wheelchair": "yes"
#       }
#     },
#     {
#       "type": "node",
#       "id": 11922169569,
#       "lat": 32.7770074,
#       "lon": 129.8634063,
#       "tags": {
#         "amenity": "cafe",
#         "cuisine": "japanese",
#         "diet:vegan": "yes",
#         "diet:vegetarian": "yes",
#         "name:en": "Blue Bronze Store"
#       }
#     },
#     {
#       "type": "node",
#       "id": 12177836984,
#       "lat": 32.7431671,
#       "lon": 129.8806961,
#       "tags": {
#         "amenity": "cafe",
#         "check_date": "2024-09-15",
#         "level": "0",
#         "name": "ツル茶ん"
#       }
#     },
#     {
#       "type": "way",
#       "id": 718120938,
#       "bounds": {
#         "minlat": 32.7720002,
#         "minlon": 129.8635792,
#         "maxlat": 32.7722213,
#         "maxlon": 129.8638748
#       },
#       "nodes": [
#         6743991103,
#         6743991100,
#         6743991101,
#         6743991102,
#         6743991103
#       ],
#       "geometry": [
#         {
#           "lat": 32.7720002,
#           "lon": 129.863614
#         },
#         {
#           "lat": 32.7721046,
#           "lon": 129.8635792
#         },
#         {
#           "lat": 32.7722213,
#           "lon": 129.8638125
#         },
#         {
#           "lat": 32.7721378,
#           "lon": 129.8638748
#         },
#         {
#           "lat": 32.7720002,
#           "lon": 129.863614
#         }
#       ],
#       "tags": {
#         "amenity": "cafe",
#         "building": "yes",
#         "cuisine": "tea",
#         "name": "寳來軒",
#         "name:ja-Hira": "ほうらいけん",
#         "name:ja_rm": "hōrai ken",
#         "name:zh-Hans": "宝来轩",
#         "name:zh-Hant": "寳來軒",
#         "name:zh-Latn-pinyin": "bǎolái xuān",
#         "source": "GSImaps/std"
#       }
#     },
#     {
#       "type": "way",
#       "id": 727050168,
#       "bounds": {
#         "minlat": 32.7593766,
#         "minlon": 129.9475539,
#         "maxlat": 32.7595458,
#         "maxlon": 129.9477869
#       },
#       "nodes": [
#         6813744839,
#         6813744840,
#         6813744841,
#         6813744842,
#         6813744843,
#         6813744844,
#         6813744845,
#         6813744846,
#         6813744839
#       ],
#       "geometry": [
#         {
#           "lat": 32.7594281,
#           "lon": 129.9475539
#         },
#         {
#           "lat": 32.7593766,
#           "lon": 129.9476739
#         },
#         {
#           "lat": 32.759433,
#           "lon": 129.9477127
#         },
#         {
#           "lat": 32.7594122,
#           "lon": 129.9477586
#         },
#         {
#           "lat": 32.7594577,
#           "lon": 129.9477869
#         },
#         {
#           "lat": 32.7595458,
#           "lon": 129.9475986
#         },
#         {
#           "lat": 32.7594963,
#           "lon": 129.947568
#         },
#         {
#           "lat": 32.7594854,
#           "lon": 129.9475927
#         },
#         {
#           "lat": 32.7594281,
#           "lon": 129.9475539
#         }
#       ],
#       "tags": {
#         "amenity": "cafe",
#         "building": "yes"
#       }
#     }
#   ]
# }
# 23

# %% [markdown]
# ### Overpass API で取得したデータを GeoJSON に変換する

# %%
def convert_overpass_to_geojson(overpass_response):
    geojson = {
        "type": "FeatureCollection",
        "features": []
    }

    for element in overpass_response['elements']:
        feature = {
            "type": "Feature",
            "properties": {},
            "geometry": {}
        }

        if 'tags' in element:
            feature['properties'] = element['tags']

        if element['type'] == 'node':
            feature['geometry'] = {
                "type": "Point",
                "coordinates": [element['lon'], element['lat']]
            }

        elif element['type'] == 'way':
            feature['geometry'] = {
                "type": "Polygon" if 'nodes' in element else "LineString",
                "coordinates": [[(n['lon'], n['lat']) for n in overpass_response['elements'] if n['id'] in element['nodes']]]
            }

        elif element['type'] == 'relation':
            # Handle relations as MultiPolygons (simplified)
            feature['geometry'] = {"type": "MultiPolygon", "coordinates": []}
            for member in element['members']:
                if member['type'] == 'way':
                    way_id = member['ref']
                    way = next((w for w in overpass_response['elements'] if w['id'] == way_id and w['type'] == 'way'), None)
                    if way:
                        coordinates = [[(n['lon'], n['lat']) for n in overpass_response['elements'] if n['id'] in way['nodes']]]
                        if coordinates:
                            feature['geometry']['coordinates'].append([coordinates[0]]) #Multipolygonなので、さらにリストで囲む

        geojson["features"].append(feature)
    return geojson

# %%
geojson_data = convert_overpass_to_geojson(overpass_response)
print(json.dumps(geojson_data, indent=2, ensure_ascii=False))
# Out:
# {
#   "type": "FeatureCollection",
#   "features": [
#     {
#       "type": "Feature",
#       "properties": {
#         "amenity": "cafe",
#         "layer": "1",
#         "level": "1",
#         "name": "タイム",
#         "source": "image,2013-09;Bing,2011-07-11"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           129.8703754,
#           32.7360454
#         ]
#       }
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "amenity": "cafe",
#         "name": "BRICK CAFE",
#         "source": "image,2013-09;Bing,2011-07-11"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           129.8695208,
#           32.7359147
#         ]
#       }
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "amenity": "cafe",
#         "name": "トレビ",
#         "name:en": "TOREVI",
#         "source": "image,2013-09;Bing,2011-07-11"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           129.8698889,
#           32.7357577
#         ]
#       }
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "amenity": "cafe",
#         "name": "CAFE 1571",
#         "source": "image,2013-09;Bing,2011-07-11"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           129.8700096,
#           32.7350887
#         ]
#       }
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "amenity": "cafe"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           129.8591467,
#           32.7833873
#         ]
#       }
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "amenity": "cafe",
#         "branch": "長崎西浜通り店",
#         "brand": "カフェ・ベローチェ",
#         "brand:en": "CAFFÈ VELOCE",
#         "brand:ja": "カフェ・ベローチェ",
#         "brand:wikidata": "Q11294597",
#         "brand:wikipedia": "ja:カフェ・ベローチェ",
#         "cuisine": "coffee_shop",
#         "internet_access": "wlan",
#         "internet_access:fee": "no",
#         "name": "カフェ・ベローチェ",
#         "name:en": "CAFFÈ VELOCE",
#         "name:ja": "カフェ・ベローチェ",
#         "opening_hours": "Mo-Su 07:15-23:00",
#         "outdoor_seating": "no",
#         "smoking": "isolated",
#         "takeaway": "yes",
#         "website": "https://chatnoir-company.com/chatnoir/ShopSearch?shop_code=378"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           129.8765886,
#           32.7431669
#         ]
#       }
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "amenity": "cafe",
#         "name": "Blueprint"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           129.8712687,
#           32.7458305
#         ]
#       }
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "amenity": "cafe",
#         "name": "笑くぼ",
#         "name:en": "Ekubo"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           129.9107791,
#           32.7040395
#         ]
#       }
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "amenity": "cafe",
#         "name:en": "Juma Cafe"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           129.8657634,
#           32.7758285
#         ]
#       }
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "amenity": "cafe",
#         "internet_access": "no",
#         "name": "Attic Coffee"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           129.8706219,
#           32.7437759
#         ]
#       }
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "amenity": "cafe",
#         "internet_access": "wlan",
#         "internet_access:fee": "no",
#         "name": "Branch Otto",
#         "opening_hours": "10:30-22:00",
#         "outdoor_seating": "yes",
#         "wheelchair": "yes"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           129.8741488,
#           32.7428008
#         ]
#       }
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "amenity": "cafe",
#         "brand": "スターバックス",
#         "brand:en": "Starbucks",
#         "brand:ja": "スターバックス",
#         "brand:wikidata": "Q37158",
#         "brand:wikipedia": "en:Starbucks",
#         "cuisine": "coffee_shop",
#         "name": "スターバックス",
#         "name:en": "Starbucks",
#         "name:ja": "スターバックス",
#         "official_name": "スターバックスコーヒー",
#         "official_name:en": "Starbucks Coffee",
#         "official_name:ja": "スターバックスコーヒー",
#         "opening_hours": "Mo-Su 07:30-22:00",
#         "outdoor_seating": "yes",
#         "takeaway": "yes"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           129.8711927,
#           32.7520273
#         ]
#       }
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "amenity": "cafe",
#         "name": "CAFFE VELOCE"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           129.8801211,
#           32.7434292
#         ]
#       }
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "amenity": "cafe",
#         "name:en": "Café Maman"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           129.8728574,
#           32.7347773
#         ]
#       }
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "amenity": "cafe",
#         "name": "からしま自家焙煎珈琲舎"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           129.8358444,
#           32.8050515
#         ]
#       }
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "amenity": "cafe",
#         "name:en": "Cafe Dining Mammy"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           129.8656126,
#           32.7755426
#         ]
#       }
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "amenity": "cafe",
#         "name": "長崎県美術館カフェ",
#         "twitter": "npam_cafe",
#         "website": "http://www.nagasaki-museum.jp/goods2/?mainlabel=%E3%82%AB%E3%83%95%E3%82%A7"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           129.8707975,
#           32.7417137
#         ]
#       }
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "addr:block_number": "2",
#         "addr:city": "長崎市",
#         "addr:housename": "街ビル 2",
#         "addr:neighbourhood": "浜町",
#         "addr:province": "長崎県",
#         "air_conditioning": "yes",
#         "amenity": "cafe",
#         "contact:email": "june6coffee@gmail.com",
#         "contact:instagram": "junecoffee_hama",
#         "diet:vegan": "limited",
#         "diet:vegan:description": "Only Soy milk",
#         "diet:vegetarian": "yes",
#         "indoor_seating": "yes",
#         "level": "0",
#         "level:ref": "1F",
#         "name": "June Coffee 浜の町店",
#         "opening_hours": "Mo-Su 10:30-18:30; closed \"年末年始\"",
#         "outdoor_seating": "no",
#         "payment:credit_cards": "yes",
#         "payment:debit_cards": "yes",
#         "smoking": "no",
#         "toilets": "yes",
#         "wheelchair": "yes"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           129.8779672,
#           32.7450868
#         ]
#       }
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "addr:block_number": "2",
#         "addr:city": "長崎市",
#         "addr:housenumber": "5",
#         "addr:neighbourhood": "大黒町",
#         "addr:province": "長崎県",
#         "air_conditioning": "yes",
#         "amenity": "cafe",
#         "contact:instagram": "ngs_coffee",
#         "diet:vegan": "no",
#         "diet:vegetarian": "yes",
#         "indoor_seating": "yes",
#         "level": "0",
#         "level:ref": "1F",
#         "name": "NGS Coffee",
#         "opening_hours": "Mo-Su 08:00-20:00",
#         "operator:website": "https://neutral-holdings.co.jp",
#         "outdoor_seating": "no",
#         "payment:credit_cards": "yes",
#         "payment:debit_cards": "yes",
#         "phone": "+81 095-895-5727",
#         "smoking": "no",
#         "website": "https://fuk-coffee.com",
#         "wheelchair": "yes"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           129.8712324,
#           32.7535974
#         ]
#       }
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "amenity": "cafe",
#         "cuisine": "japanese",
#         "diet:vegan": "yes",
#         "diet:vegetarian": "yes",
#         "name:en": "Blue Bronze Store"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           129.8634063,
#           32.7770074
#         ]
#       }
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "amenity": "cafe",
#         "check_date": "2024-09-15",
#         "level": "0",
#         "name": "ツル茶ん"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           129.8806961,
#           32.7431671
#         ]
#       }
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "amenity": "cafe",
#         "building": "yes",
#         "cuisine": "tea",
#         "name": "寳來軒",
#         "name:ja-Hira": "ほうらいけん",
#         "name:ja_rm": "hōrai ken",
#         "name:zh-Hans": "宝来轩",
#         "name:zh-Hant": "寳來軒",
#         "name:zh-Latn-pinyin": "bǎolái xuān",
#         "source": "GSImaps/std"
#       },
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           []
#         ]
#       }
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "amenity": "cafe",
#         "building": "yes"
#       },
#       "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#           []
#         ]
#       }
#     }
#   ]
# }

# %% [markdown]
# ### GeoJSON を地図上に表示する

# %%
import folium

m = folium.Map(location=[0, 0], zoom_start=2)

folium.GeoJson(geojson_data).add_to(m)

bounds = folium.GeoJson(geojson_data).get_bounds()
if bounds:
    m.fit_bounds(bounds)

display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ee087303d36854c373227dd0d0dc4ff1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ee087303d36854c373227dd0d0dc4ff1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ee087303d36854c373227dd0d0dc4ff1 = L.map(
#                 &quot;map_ee087303d36854c373227dd0d0dc4ff1&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ce9692617d0493611475507aea27f6b7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ce9692617d0493611475507aea27f6b7.addTo(map_ee087303d36854c373227dd0d0dc4ff1);
#
#
#
#         function geo_json_e10d0c94b2992a5279a4eda49567ae6b_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_e10d0c94b2992a5279a4eda49567ae6b = L.geoJson(null, {
#                 onEachFeature: geo_json_e10d0c94b2992a5279a4eda49567ae6b_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_e10d0c94b2992a5279a4eda49567ae6b_add (data) {
#             geo_json_e10d0c94b2992a5279a4eda49567ae6b
#                 .addData(data);
#         }
#             geo_json_e10d0c94b2992a5279a4eda49567ae6b_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [129.8703754, 32.7360454], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;amenity&quot;: &quot;cafe&quot;, &quot;layer&quot;: &quot;1&quot;, &quot;level&quot;: &quot;1&quot;, &quot;name&quot;: &quot;\u30bf\u30a4\u30e0&quot;, &quot;source&quot;: &quot;image,2013-09;Bing,2011-07-11&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [129.8695208, 32.7359147], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;amenity&quot;: &quot;cafe&quot;, &quot;name&quot;: &quot;BRICK CAFE&quot;, &quot;source&quot;: &quot;image,2013-09;Bing,2011-07-11&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [129.8698889, 32.7357577], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;amenity&quot;: &quot;cafe&quot;, &quot;name&quot;: &quot;\u30c8\u30ec\u30d3&quot;, &quot;name:en&quot;: &quot;TOREVI&quot;, &quot;source&quot;: &quot;image,2013-09;Bing,2011-07-11&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [129.8700096, 32.7350887], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;amenity&quot;: &quot;cafe&quot;, &quot;name&quot;: &quot;CAFE 1571&quot;, &quot;source&quot;: &quot;image,2013-09;Bing,2011-07-11&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [129.8591467, 32.7833873], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;amenity&quot;: &quot;cafe&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [129.8765886, 32.7431669], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;amenity&quot;: &quot;cafe&quot;, &quot;branch&quot;: &quot;\u9577\u5d0e\u897f\u6d5c\u901a\u308a\u5e97&quot;, &quot;brand&quot;: &quot;\u30ab\u30d5\u30a7\u30fb\u30d9\u30ed\u30fc\u30c1\u30a7&quot;, &quot;brand:en&quot;: &quot;CAFF\u00c8 VELOCE&quot;, &quot;brand:ja&quot;: &quot;\u30ab\u30d5\u30a7\u30fb\u30d9\u30ed\u30fc\u30c1\u30a7&quot;, &quot;brand:wikidata&quot;: &quot;Q11294597&quot;, &quot;brand:wikipedia&quot;: &quot;ja:\u30ab\u30d5\u30a7\u30fb\u30d9\u30ed\u30fc\u30c1\u30a7&quot;, &quot;cuisine&quot;: &quot;coffee_shop&quot;, &quot;internet_access&quot;: &quot;wlan&quot;, &quot;internet_access:fee&quot;: &quot;no&quot;, &quot;name&quot;: &quot;\u30ab\u30d5\u30a7\u30fb\u30d9\u30ed\u30fc\u30c1\u30a7&quot;, &quot;name:en&quot;: &quot;CAFF\u00c8 VELOCE&quot;, &quot;name:ja&quot;: &quot;\u30ab\u30d5\u30a7\u30fb\u30d9\u30ed\u30fc\u30c1\u30a7&quot;, &quot;opening_hours&quot;: &quot;Mo-Su 07:15-23:00&quot;, &quot;outdoor_seating&quot;: &quot;no&quot;, &quot;smoking&quot;: &quot;isolated&quot;, &quot;takeaway&quot;: &quot;yes&quot;, &quot;website&quot;: &quot;https://chatnoir-company.com/chatnoir/ShopSearch?shop_code=378&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [129.8712687, 32.7458305], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;amenity&quot;: &quot;cafe&quot;, &quot;name&quot;: &quot;Blueprint&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [129.9107791, 32.7040395], &quot;type&quot;: &quot;Point&quot;}, &quot;properties&quot;: {&quot;amenity&quot;: &quot;cafe&quot;, &quot;name&quot;: &quot;\u7b11\u304f\u307c&quot;, &quot;name:en&quot;: &quot;Ekubo&quot;}, &quot;type&quot;: &quot;Feature&
